# %% [markdown]
# Name: Jay Nakum

# %% [markdown]
# Roll No.: 20BCP304D

# %% [markdown]
# # Assignment 11

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyfpgrowth as fp
import warnings
warnings.simplefilter('ignore')

# %%
data = pd.read_excel('Online Retail.xlsx')
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
data['Description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     2369
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
#                                        ...
# Missing                                   1
# historic computer difference?....se       1
# DUSTY PINK CHRISTMAS TREE 30CM            1
# WRAP BLUE RUSSIAN FOLKART                 1
# PINK BERTIE MOBILE PHONE CHARM            1
# Name: Description, Length: 4223, dtype: int64

# %%
transactions_france=data[['InvoiceNo','Description','Quantity']].loc[data['Country']=='France']

# %%
transactions_france
# Out:
#        InvoiceNo                      Description  Quantity
# 26        536370        ALARM CLOCK BAKELIKE PINK        24
# 27        536370        ALARM CLOCK BAKELIKE RED         24
# 28        536370       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370                 STARS GIFT TAPE         24
# ...          ...                              ...       ...
# 541904    581587      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587    BAKING SET 9 PIECE RETROSPOT          3
#
# [8557 rows x 3 columns]

# %%
transactions_france.sort_values('Quantity')
# Out:
#        InvoiceNo                          Description  Quantity
# 508002   C579192               WRAP CHRISTMAS VILLAGE      -250
# 497495   C578377     FRIDGE MAGNETS US DINER ASSORTED      -120
# 497496   C578377  FRIDGE MAGNETS LES ENFANTS ASSORTED      -120
# 497497   C578377        FRIDGE MAGNETS LA VIE EN ROSE      -120
# 508004   C579192               CARD CHRISTMAS VILLAGE       -72
# ...          ...                                  ...       ...
# 423740    573153             JUMBO BAG VINTAGE DOILY        300
# 423739    573153              JUMBO BAG PINK POLKADOT       300
# 222950    556463             PENS ASSORTED FUNNY FACE       360
# 52431     540789   MINI WOODEN HAPPY BIRTHDAY GARLAND       576
# 423711    573153                   RABBIT NIGHT LIGHT       912
#
# [8557 rows x 3 columns]

# %%
transactions_france=transactions_france.loc[transactions_france['Quantity']>0]

# %%
transactions_france
# Out:
#        InvoiceNo                      Description  Quantity
# 26        536370        ALARM CLOCK BAKELIKE PINK        24
# 27        536370        ALARM CLOCK BAKELIKE RED         24
# 28        536370       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370                 STARS GIFT TAPE         24
# ...          ...                              ...       ...
# 541904    581587      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587    BAKING SET 9 PIECE RETROSPOT          3
#
# [8408 rows x 3 columns]

# %%
transactions_france.groupby(['InvoiceNo','Description']).agg({"Quantity": "sum"}).head(20)
# Out:
#                                                Quantity
# InvoiceNo Description
# 536370     SET 2 TEA TOWELS I LOVE LONDON            24
#           ALARM CLOCK BAKELIKE GREEN                 12
#           ALARM CLOCK BAKELIKE PINK                  24
#           ALARM CLOCK BAKELIKE RED                   24
#           CHARLOTTE BAG DOLLY GIRL DESIGN            20
#           CIRCUS PARADE LUNCH BOX                    24
#           INFLATABLE POLITICAL GLOBE                 48
#           LUNCH BOX I LOVE LONDON                    24
#           MINI JIGSAW CIRCUS PARADE                  24
#           MINI JIGSAW SPACEBOY                       24
#           MINI PAINT SET VINTAGE                     36
#           PANDA AND BUNNIES STICKER SHEET            12
#           POSTAGE                                     3
#           RED TOADSTOOL LED NIGHT LIGHT              24
#           ROUND SNACK BOXES SET OF4 WOODLAND         24
#           SET/2 RED RETROSPOT TEA TOWELS             18
#           SPACEBOY LUNCH BOX                         24
#           STARS GIFT TAPE                            24
#           VINTAGE HEADS AND TAILS CARD GAME          24
#           VINTAGE SEASIDE JIGSAW PUZZLES             12

# %%
transactions_france['Quantity']=1

# %%
transactions_france
# Out:
#        InvoiceNo                      Description  Quantity
# 26        536370        ALARM CLOCK BAKELIKE PINK         1
# 27        536370        ALARM CLOCK BAKELIKE RED          1
# 28        536370       ALARM CLOCK BAKELIKE GREEN         1
# 29        536370  PANDA AND BUNNIES STICKER SHEET         1
# 30        536370                 STARS GIFT TAPE          1
# ...          ...                              ...       ...
# 541904    581587      PACK OF 20 SPACEBOY NAPKINS         1
# 541905    581587     CHILDREN'S APRON DOLLY GIRL          1
# 541906    581587    CHILDRENS CUTLERY DOLLY GIRL          1
# 541907    581587  CHILDRENS CUTLERY CIRCUS PARADE         1
# 541908    581587    BAKING SET 9 PIECE RETROSPOT          1
#
# [8408 rows x 3 columns]

# %%
table=pd.pivot_table(transactions_france,values='Quantity',index=['InvoiceNo'],columns=['Description'])

# %%
table
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                  NaN                 NaN
# 536852                                  NaN                 NaN
# 536974                                  NaN                 NaN
# 537065                                  NaN                 NaN
# 537463                                  NaN                 NaN
# ...                                     ...                 ...
# 580986                                  NaN                 NaN
# 581001                                  NaN                 NaN
# 581171                                  NaN                 NaN
# 581279                                  NaN                 NaN
# 581587                                  NaN                 NaN
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                NaN                       NaN
# 536852                                NaN                       NaN
# 536974                                NaN                       NaN
# 537065                                NaN                       NaN
# 537463                                NaN                       NaN
# ...                                   ...                       ...
# 580986                                NaN                       NaN
# 581001                                NaN                       NaN
# 581171                                NaN                       NaN
# 581279                                NaN                       NaN
# 581587                                NaN                       NaN
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536370                                    1.0                      NaN
# 536852                                    NaN                      NaN
# 536974                                    NaN                      NaN
# 537065                                    NaN                      NaN
# 537463                                    NaN                      NaN
# ...                                       ...                      ...
# 580986                                    NaN                      NaN
# 581001                                    NaN                      NaN
# 581171                                    NaN                      NaN
# 581279                                    NaN                      NaN
# 581587                                    NaN                      NaN
#
# Description   TRELLIS COAT RACK  10 COLOUR SPACEBOY PEN  \
# InvoiceNo
# 536370                      NaN                     NaN
# 536852                      NaN                     NaN
# 536974                      NaN                     NaN
# 537065                      NaN                     NaN
# 537463                      NaN                     NaN
# ...                         ...                     ...
# 580986                      NaN                     NaN
# 581001                      NaN                     NaN
# 581171                      NaN                     NaN
# 581279                      NaN                     NaN
# 581587                      NaN                     NaN
#
# Description  12 COLOURED PARTY BALLOONS  12 EGG HOUSE PAINTED WOOD  ...  \
# InvoiceNo                                                           ...
# 536370                              NaN                        NaN  ...
# 536852                              NaN                        NaN  ...
# 536974                              NaN                        NaN  ...
# 537065                              NaN                        NaN  ...
# 537463                              NaN                        NaN  ...
# ...                                 ...                        ...  ...
# 580986                              NaN                        NaN  ...
# 581001                              NaN                        NaN  ...
# 581171                              NaN                        NaN  ...
# 581279                              NaN                        NaN  ...
# 581587                              NaN                        NaN  ...
#
# Description  WRAP VINTAGE PETALS  DESIGN  YELLOW COAT RACK PARIS FASHION  \
# InvoiceNo
# 536370                               NaN                             NaN
# 536852                               NaN                             NaN
# 536974                               NaN                             NaN
# 537065                               NaN                             NaN
# 537463                               NaN                             NaN
# ...                                  ...                             ...
# 580986                               NaN                             NaN
# 581001                               NaN                             NaN
# 581171                               NaN                             NaN
# 581279                               NaN                             NaN
# 581587                               NaN                             NaN
#
# Description  YELLOW GIANT GARDEN THERMOMETER  YELLOW SHARK HELICOPTER  \
# InvoiceNo
# 536370                                   NaN                      NaN
# 536852                                   NaN                      NaN
# 536974                                   NaN                      NaN
# 537065                                   NaN                      NaN
# 537463                                   NaN                      NaN
# ...                                      ...                      ...
# 580986                                   NaN                      NaN
# 581001                                   NaN                      NaN
# 581171                                   NaN                      NaN
# 581279                                   NaN                      NaN
# 581587                                   NaN                      NaN
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536370                              NaN                        NaN
# 536852                              NaN                        NaN
# 536974                              NaN                        NaN
# 537065                              NaN                        NaN
# 537463                              NaN                        NaN
# ...                                 ...                        ...
# 580986                              NaN                        NaN
# 581001                              NaN                        NaN
# 581171                              NaN                        NaN
# 581279                              NaN                        NaN
# 581587                              NaN                        NaN
#
# Description  ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536370                              NaN                          NaN
# 536852                              NaN                          NaN
# 536974                              NaN                          NaN
# 537065                              NaN                          NaN
# 537463                              NaN                          NaN
# ...                                 ...                          ...
# 580986                              NaN                          NaN
# 581001                              NaN                          NaN
# 581171                              NaN                          NaN
# 581279                              NaN                          NaN
# 581587                              NaN                          NaN
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                  NaN                              NaN
# 536852                                  NaN                              NaN
# 536974                                  NaN                              NaN
# 537065                                  NaN                              NaN
# 537463                                  NaN                              NaN
# ...                                     ...                              ...
# 580986                                  NaN                              NaN
# 581001                                  NaN                              NaN
# 581171                                  NaN                              NaN
# 581279                                  NaN                              NaN
# 581587                                  NaN                              NaN
#
# [392 rows x 1564 columns]

# %%
t=[]
for i in range(0,392):
   t.append([table.columns[j] for j in range(0,1563) if table.iloc[i][j]==1])

# %%
t
# Out:
# [[' SET 2 TEA TOWELS I LOVE LONDON ',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'CIRCUS PARADE LUNCH BOX ',
#   'INFLATABLE POLITICAL GLOBE ',
#   'LUNCH BOX I LOVE LONDON',
#   'MINI JIGSAW CIRCUS PARADE ',
#   'MINI JIGSAW SPACEBOY',
#   'MINI PAINT SET VINTAGE ',
#   'PANDA AND BUNNIES STICKER SHEET',
#   'POSTAGE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET/2 RED RETROSPOT TEA TOWELS ',
#   'SPACEBOY LUNCH BOX ',
#   'STARS GIFT TAPE ',
#   'VINTAGE HEADS AND TAILS CARD GAME ',
#   'VINTAGE SEASIDE JIGSAW PUZZLES'],
#  ['CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'MINI JIGSAW DOLLY GIRL',
#   'MINI JIGSAW SPACEBOY',
#   'PICTURE DOMINOES',
#   'POLKADOT RAIN HAT ',
#   'POSTAGE',
#   'VINTAGE HEADS AND TAILS CARD GAME '],
#  ['ASSORTED COLOUR MINI CASES',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL PINK',
#   'EDWARDIAN PARASOL RED',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'LUNCH BOX I LOVE LONDON',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'POSTAGE',
#   'RED  HARMONICA IN BOX ',
#   'RED RETROSPOT MINI CASES',
#   'RIBBON REEL POLKADOTS ',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'TEA PARTY BIRTHDAY CARD'],
#  ['5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'ASSORTED COLOUR MINI CASES',
#   'BASKET OF TOADSTOOLS',
#   'BLUE 3 PIECE POLKADOT CUTLERY SET',
#   'BLUE GEISHA GIRL ',
#   'BREAD BIN DINER STYLE RED ',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'CERAMIC STRAWBERRY MONEY BOX',
#   'CERAMIC STRAWBERRY TRINKET TRAY',
#   'CHERRY BLOSSOM  DECORATIVE FLASK',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CHILDS BREAKFAST SET DOLLY GIRL ',
#   'CHILDS BREAKFAST SET SPACEBOY ',
#   'CLASSICAL ROSE SMALL VASE',
#   'DECORATIVE CATS BATHROOM BOTTLE',
#   'DINOSAUR KEYRINGS ASSORTED',
#   'FIVE HEART HANGING DECORATION',
#   'GREEN 3 PIECE POLKADOT CUTLERY SET',
#   'GREEN GEISHA GIRL ',
#   'GUMBALL COAT RACK',
#   'HAND WARMER RED RETROSPOT',
#   'HOT WATER BOTTLE BABUSHKA ',
#   'LUNCH BAG CARS BLUE',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   "NURSE'S BAG SOFT TOY",
#   'PACK OF 12 CIRCUS PARADE TISSUES ',
#   'PACK OF 12 RED RETROSPOT TISSUES ',
#   'PACK OF 12 SPACEBOY TISSUES',
#   'PACK OF 12 SUKI TISSUES ',
#   'PACK OF 12 WOODLAND TISSUES ',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'PARTY BUNTING',
#   'PARTY TIME PENCIL ERASERS',
#   'PINK  HONEYCOMB PAPER BALL ',
#   'PINK PAINTED KASHMIRI CHAIR',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POLKADOT RAIN HAT ',
#   'POSTAGE',
#   'RAIN PONCHO RETROSPOT',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'RED GINGHAM TEDDY BEAR ',
#   'RED RETROSPOT BUTTER DISH',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT PURSE ',
#   'REGENCY CAKESTAND 3 TIER',
#   'RETROSPOT LAMP',
#   'RETROSPOT LARGE MILK JUG',
#   'ROSE COTTAGE KEEPSAKE BOX ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET OF 6 3D KIT CARDS FOR KIDS',
#   'SET OF 6 SOLDIER SKITTLES',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TOOL BOX SOFT TOY ',
#   'TRADITIONAL WOODEN CATCH CUP GAME '],
#  ['BIG DOUGHNUT FRIDGE MAGNETS',
#   'BLACK RECORD COVER FRAME',
#   'BOOM BOX SPEAKER BOYS',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'CANDY SHOP  STICKER SHEET',
#   'COFFEE MUG CAT + BIRD DESIGN',
#   'COFFEE MUG DOG + BALL DESIGN',
#   'DOORMAT RESPECTABLE HOUSE',
#   'FANCY FONT BIRTHDAY CARD, ',
#   'GUMBALL COAT RACK',
#   'IVORY DINER WALL CLOCK',
#   'JAM MAKING SET PRINTED',
#   'LOVELY BONBON STICKER SHEET',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'METAL SIGN TAKE IT OR LEAVE IT ',
#   'OFFICE MUG WARMER PINK',
#   'OFFICE MUG WARMER POLKADOT',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RECORD FRAME 7" SINGLE SIZE ',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT CUP',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'ROBOT BIRTHDAY CARD',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/4 SKULL BADGES',
#   'SKULLS  WATER TRANSFER TATTOOS ',
#   'SNOWSTORM PHOTO FRAME FRIDGE MAGNET',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TABLECLOTH RED APPLES DESIGN ',
#   'TEA BAG PLATE RED RETROSPOT',
#   'TEA PARTY BIRTHDAY CARD',
#   'WOODLAND  STICKERS',
#   'WOODLAND CHARLOTTE BAG'],
#  ['10 COLOUR SPACEBOY PEN',
#   'BIRD HOUSE HOT WATER BOTTLE',
#   'CLOTHES PEGS RETROSPOT PACK 24 ',
#   'DELUXE SEWING KIT ',
#   'FELTCRAFT DOLL MARIA',
#   'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'GREY HEART HOT WATER BOTTLE',
#   'HOT WATER BOTTLE BABUSHKA ',
#   'HOT WATER BOTTLE TEA AND SYMPATHY',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG SUKI  DESIGN ',
#   'MAGIC DRAWING SLATE CIRCUS PARADE  ',
#   "POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE BEDROOM ",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'POSTAGE',
#   'RETROSPOT HEART HOT WATER BOTTLE',
#   'SCOTTIE DOG HOT WATER BOTTLE'],
#  ['BLUE SCANDINAVIAN PAISLEY WRAP',
#   'FAIRY CAKE BIRTHDAY CANDLE SET',
#   'MAKE YOUR OWN MONSOON CARD KIT',
#   'MAKE YOUR OWN PLAYTIME CARD KIT',
#   "PAPER CHAIN KIT 50'S CHRISTMAS ",
#   'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#   'POSTAGE',
#   'TEA TIME PARTY BUNTING',
#   'TRADITIONAL CHRISTMAS RIBBONS',
#   'VINTAGE CARAVAN GIFT WRAP',
#   'WRAP I LOVE LONDON '],
#  ['CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'CHILDRENS DOLLY GIRL MUG',
#   'CHRISTMAS RETROSPOT ANGEL WOOD',
#   'CLOTHES PEGS RETROSPOT PACK 24 ',
#   'DOORMAT RED RETROSPOT',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'FELT TOADSTOOL  SMALL',
#   'MEASURING TAPE BABUSHKA RED',
#   'POSTAGE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RED WOOLLY HOTTIE WHITE HEART.',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'SET OF 2 ROUND TINS CAMEMBERT '],
#  ['POSTAGE', 'RECIPE BOX RETROSPOT ', 'RED RETROSPOT CAKE STAND'],
#  ['60 CAKE CASES DOLLY GIRL DESIGN',
#   '72 SWEETHEART FAIRY CAKE CASES',
#   'BLUE PARTY BAGS ',
#   "CHILDREN'S APRON DOLLY GIRL ",
#   "CHILDREN'S CIRCUS PARADE MUG",
#   "CHILDREN'S SPACEBOY MUG",
#   'CHILDRENS APRON APPLES DESIGN',
#   'CHILDRENS DOLLY GIRL MUG',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CIRCUS PARADE CHILDRENS EGG CUP ',
#   'CUPCAKE LACE PAPER SET 6',
#   'DOLLY GIRL CHILDRENS EGG CUP',
#   'DOLLY GIRL LUNCH BOX',
#   'EASTER TIN BUNNY BOUQUET',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'OVEN MITT APPLES DESIGN',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'PINK CREAM FELT CRAFT TRINKET BOX ',
#   'PINK PARTY BAGS',
#   'POSTAGE',
#   'RED RETROSPOT CAKE STAND',
#   'RED RETROSPOT OVEN GLOVE ',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET/10 IVORY POLKADOT PARTY CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SPACEBOY CHILDRENS EGG CUP',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TABLECLOTH RED APPLES DESIGN ',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'WRAP GREEN PEARS ',
#   'WRAP RED APPLES '],
#  ['4 TRADITIONAL SPINNING TOPS',
#   '6 RIBBONS RUSTIC CHARM',
#   'ASSORTED COLOUR MINI CASES',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'BIRD DECORATION RED RETROSPOT',
#   'EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL RED',
#   'HAIRCLIPS FORTIES FABRIC ASSORTED',
#   'INFLATABLE POLITICAL GLOBE ',
#   'JAM MAKING SET PRINTED',
#   'JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG SUKI  DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'METAL DECORATION NAUGHTY CHILDREN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RIBBON REEL MAKING SNOWMEN ',
#   'RIBBON REEL SNOWY VILLAGE',
#   'RIBBON REEL STRIPES DESIGN ',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'SET/3 DECOUPAGE STACKING TINS',
#   'SKULL LUNCH BOX WITH CUTLERY ',
#   'SMALL POPCORN HOLDER',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TOADSTOOL MONEY BOX',
#   'VINTAGE HEADS AND TAILS CARD GAME '],
#  ['ASSORTED COLOUR BIRD ORNAMENT',
#   'BLUE HARMONICA IN BOX ',
#   'CLOTHES PEGS RETROSPOT PACK 24 ',
#   'DOORMAT RED RETROSPOT',
#   'DOORMAT UNION FLAG',
#   'ELEPHANT, BIRTHDAY CARD, ',
#   'INFLATABLE POLITICAL GLOBE ',
#   'LUNCH BAG RED RETROSPOT',
#   'PICTURE DOMINOES',
#   'POSTAGE',
#   'RED  HARMONICA IN BOX ',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT TRADITIONAL TEAPOT ',
#   'RETROSPOT LARGE MILK JUG',
#   'TRADITIONAL MODELLING CLAY',
#   'WOODEN BOX OF DOMINOES'],
#  ['12 PENCILS TALL TUBE RED RETROSPOT',
#   '6 RIBBONS EMPIRE  ',
#   'AGED GLASS SILVER T-LIGHT HOLDER',
#   'AIRLINE BAG VINTAGE JET SET BROWN',
#   'AIRLINE BAG VINTAGE JET SET RED',
#   'ANTIQUE ALL GLASS CANDLESTICK',
#   'ANTIQUE GLASS PEDESTAL BOWL',
#   'ANTIQUE SILVER TEA GLASS ENGRAVED',
#   'ASSTD DESIGN 3D PAPER STICKERS',
#   'BALLOONS  WRITING SET ',
#   'BLACK CANDELABRA T-LIGHT HOLDER',
#   'BLUE TEA TOWEL CLASSIC DESIGN',
#   'CAROUSEL DESIGN WASHBAG',
#   'CHRISTMAS METAL TAGS ASSORTED ',
#   'CIRCUS PARADE LUNCH BOX ',
#   'ETCHED GLASS COASTER',
#   'FELTCRAFT CHRISTMAS FAIRY',
#   'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'FUNKY WASHING UP GLOVES ASSORTED',
#   'GREY FLORAL FELTCRAFT SHOULDER BAG',
#   'HEART OF WICKER SMALL',
#   'KEEP OUT BOYS DOOR HANGER ',
#   'KEY FOB , BACK DOOR ',
#   'KEY FOB , SHED',
#   'LETS GO SHOPPING COTTON TOTE BAG',
#   'MAGNETS PACK OF 4 CHILDHOOD MEMORY',
#   'MAGNETS PACK OF 4 VINTAGE COLLAGE',
#   'MAGNETS PACK OF 4 VINTAGE LABELS ',
#   'METAL SIGN TAKE IT OR LEAVE IT ',
#   'MOTORING TISSUE BOX',
#   'NINJA RABBIT PINK',
#   'PACK OF 12 HEARTS DESIGN TISSUES ',
#   'PACK OF 12 PINK POLKADOT TISSUES',
#   'PACK OF 12 RED RETROSPOT TISSUES ',
#   'PACK OF 12 SUKI TISSUES ',
#   'PACK OF 12 WOODLAND TISSUES ',
#   'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#   'PHOTO CUBE',
#   'PINK CREAM FELT CRAFT TRINKET BOX ',
#   'PLACE SETTING WHITE HEART',
#   'RED RETROSPOT TISSUE BOX',
#   'RED TEA TOWEL CLASSIC DESIGN',
#   'REX CASH+CARRY JUMBO SHOPPER',
#   'RIBBON REEL CHRISTMAS SOCK BAUBLE',
#   'RIBBON REEL HEARTS DESIGN ',
#   'RIBBON REEL LACE DESIGN ',
#   'RIBBON REEL STRIPES DESIGN ',
#   'S/6 SEW ON CROCHET FLOWERS',
#   'SANDWICH BATH SPONGE',
#   'SCANDINAVIAN REDS RIBBONS',
#   'SCOTTIES DESIGN WASHBAG',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'SET OF 3 CAKE TINS PANTRY DESIGN ',
#   'SET OF 3 HEART COOKIE CUTTERS',
#   'SET OF 3 NOTEBOOKS IN PARCEL',
#   'SET OF 4 NAPKIN CHARMS CROWNS ',
#   'SET OF 4 NAPKIN CHARMS CUTLERY',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'SPACE CADET RED',
#   'SPACE OWL',
#   'SQUARECUSHION COVER PINK UNION FLAG',
#   'STRAWBERRY BATH SPONGE ',
#   'URBAN BLACK RIBBONS ',
#   'VINTAGE BILLBOARD TEA MUG',
#   'WICKER WREATH LARGE',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'ZINC METAL HEART DECORATION'],
#  ['LUNCH BAG DOLLY GIRL DESIGN'],
#  ['BLUE HARMONICA IN BOX ',
#   'FELT FARM ANIMAL WHITE BUNNY ',
#   'FELT TOADSTOOL  SMALL',
#   'MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET'],
#  ['POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'TOADSTOOL MONEY BOX'],
#  ['ASS COLOUR GLOWING TIARAS',
#   'EDWARDIAN PARASOL NATURAL',
#   'EDWARDIAN PARASOL PINK',
#   'FAIRY TALE COTTAGE NIGHTLIGHT',
#   'HAND WARMER BABUSHKA DESIGN',
#   'LUNCH BAG WOODLAND',
#   'PINK HEART SHAPE EGG FRYING PAN',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'POSTAGE',
#   'RED DRAGONFLY HELICOPTER',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'TOAST ITS - I LOVE YOU ',
#   'WOODLAND PARTY BAG + STICKER SET'],
#  ['BIG DOUGHNUT FRIDGE MAGNETS',
#   'BLACK RECORD COVER FRAME',
#   'BLUE POLKADOT CUP',
#   'BOOM BOX SPEAKER GIRLS',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'CHARLOTTE BAG PINK POLKADOT',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'CIRCUS PARADE CHILDRENS EGG CUP ',
#   'COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'DOORMAT RESPECTABLE HOUSE',
#   'DOORMAT UNION FLAG',
#   'FANCY FONT BIRTHDAY CARD, ',
#   'FIRST CLASS PASSPORT COVER ',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'JAM MAKING SET PRINTED',
#   'LARGE POPCORN HOLDER ',
#   'LONDON BUS COFFEE MUG',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'METAL SIGN TAKE IT OR LEAVE IT ',
#   'NO SINGING METAL SIGN',
#   'OFFICE MUG WARMER CHOC+BLUE',
#   'OFFICE MUG WARMER POLKADOT',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'PACK OF 72 SKULL CAKE CASES',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'PINK UNION JACK  PASSPORT COVER ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RECORD FRAME 7" SINGLE SIZE ',
#   'RED RETROSPOT MINI CASES',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/4 SKULL BADGES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SMALL POPCORN HOLDER',
#   'SNOWSTORM PHOTO FRAME FRIDGE MAGNET',
#   'SPACEBOY BIRTHDAY CARD',
#   'STARS GIFT TAPE ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TRAVEL SEWING KIT',
#   'UNION JACK FLAG PASSPORT COVER '],
#  ['CARRIAGE'],
#  ['BAKING MOULD EASTER EGG MILK CHOC',
#   'BAKING MOULD EASTER EGG WHITE CHOC',
#   'CLOTHES PEGS RETROSPOT PACK 24 ',
#   'POSTAGE'],
#  ['CAKE PLATE LOVEBIRD PINK',
#   'CAKE PLATE LOVEBIRD WHITE',
#   'METAL SIGN CUPCAKE SINGLE HOOK',
#   'METAL SIGN,CUPCAKE SINGLE HOOK'],
#  ['12 PENCIL SMALL TUBE WOODLAND',
#   '12 PENCILS SMALL TUBE RED RETROSPOT',
#   '4 TRADITIONAL SPINNING TOPS',
#   'BOOM BOX SPEAKER BOYS',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'CALENDAR PAPER CUT DESIGN',
#   'CUTE CATS TAPE',
#   "DOLLY MIXTURE CHILDREN'S UMBRELLA",
#   'DOORMAT RESPECTABLE HOUSE',
#   'FOLDING UMBRELLA CREAM POLKADOT',
#   'FOLDING UMBRELLA RED/WHITE POLKADOT',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'GUMBALL COAT RACK',
#   'JAM MAKING SET PRINTED',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'OFFICE MUG WARMER CHOC+BLUE',
#   'OFFICE MUG WARMER PINK',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POLKADOT RAIN HAT ',
#   'POSTAGE',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT CUP',
#   'ROBOT BIRTHDAY CARD',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'SET/4 SKULL BADGES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SKULLS  WATER TRANSFER TATTOOS ',
#   'TABLECLOTH RED APPLES DESIGN ',
#   'TEA BAG PLATE RED RETROSPOT',
#   'TEA PARTY BIRTHDAY CARD'],
#  ['ASSORTED BOTTLE TOP  MAGNETS ',
#   'ASSORTED COLOUR MINI CASES',
#   'BLUE ROSE FABRIC MIRROR',
#   'CALENDAR PAPER CUT DESIGN',
#   'CHERRY BLOSSOM  DECORATIVE FLASK',
#   'CIRCUS PARADE CHILDRENS EGG CUP ',
#   'CLOTHES PEGS RETROSPOT PACK 24 ',
#   'COFFEE MUG PEARS  DESIGN',
#   'EASTER TIN BUNNY BOUQUET',
#   'EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL NATURAL',
#   'EDWARDIAN PARASOL PINK',
#   'EDWARDIAN PARASOL RED',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'INFLATABLE POLITICAL GLOBE ',
#   'JAM JAR WITH PINK LID',
#   'JAM MAKING SET PRINTED',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'PACK OF 60 PINK PAISLEY CAKE CASES',
#   'PAPER BUNTING RETROSPOT',
#   'PINK DOUGHNUT TRINKET POT ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED  HARMONICA IN BOX ',
#   'RED RETROSPOT MINI CASES',
#   'REGENCY CAKESTAND 3 TIER',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'SILK PURSE BABUSHKA RED',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TEA FOR ONE POLKADOT',
#   'TEA PARTY BIRTHDAY CARD',
#   'VINTAGE HEADS AND TAILS CARD GAME ',
#   'WOODLAND PARTY BAG + STICKER SET'],
#  ['60 CAKE CASES DOLLY GIRL DESIGN',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'CERAMIC HEART FAIRY CAKE MONEY BANK',
#   'CERAMIC PIRATE CHEST MONEY BANK',
#   "DOCTOR'S BAG SOFT TOY",
#   'LUNCH BAG RED RETROSPOT',
#   'MINI FUNKY DESIGN TAPES',
#   "NURSE'S BAG SOFT TOY",
#   'PACK OF 12 RED RETROSPOT TISSUES ',
#   'PACK OF 60 DINOSAUR CAKE CASES',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PIGGY BANK RETROSPOT ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN VINTAGE PAISLEY ',
#   'POSTAGE',
#   'ROMANTIC IMAGES GIFT WRAP SET',
#   'SET 12 KIDS  WHITE CHALK STICKS',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'TOOL BOX SOFT TOY ',
#   'WOOD STAMP SET HAPPY BIRTHDAY',
#   'WOODEN CROQUET GARDEN SET',
#   'WOODEN SKITTLES GARDEN SET'],
#  ['10 COLOUR SPACEBOY PEN',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'BAKING SET SPACEBOY DESIGN',
#   'BALLOONS  WRITING SET ',
#   'BLACK/BLUE POLKADOT UMBRELLA',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'CHILDS BREAKFAST SET SPACEBOY ',
#   'EDWARDIAN PARASOL RED',
#   'FELTCRAFT DOLL MOLLY',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'JUMBO BAG RED RETROSPOT',
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'POSTAGE',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT PICNIC BAG',
#   'RED RETROSPOT SHOPPING BAG',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'STARS GIFT TAPE ',
#   'TOOL BOX SOFT TOY '],
#  ['ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'POSTAGE',
#   'RED RETROSPOT APRON ',
#   'RED RETROSPOT MINI CASES',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'STARS GIFT TAPE ',
#   'WOODLAND CHARLOTTE BAG',
#   'WOODLAND PARTY BAG + STICKER SET'],
#  ['BAKING SET 9 PIECE RETROSPOT ',
#   'CREAM FELT EASTER EGG BASKET',
#   'GUMBALL COAT RACK',
#   "NURSE'S BAG SOFT TOY",
#   'PAPER BUNTING RETROSPOT',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE',
#   'RED RETROSPOT CAKE STAND',
#   'RED RETROSPOT MINI CASES',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'SILK PURSE BABUSHKA PINK',
#   'TEA PARTY BIRTHDAY CARD',
#   'WOODEN SKITTLES GARDEN SET',
#   'WOODLAND DESIGN  COTTON TOTE BAG'],
#  ['BAKING SET 9 PIECE RETROSPOT ',
#   'CUTE CATS TAPE',
#   'EDWARDIAN PARASOL BLACK',
#   'RED POLKADOT COFFEE  MUG',
#   'RETRO PLASTIC POLKA TRAY',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'SET/2 RED RETROSPOT TEA TOWELS ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'STARS GIFT TAPE '],
#  ['ALARM CLOCK BAKELIKE CHOCOLATE',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE IVORY',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'BAKING SET SPACEBOY DESIGN',
#   'BLACK LOVE BIRD CANDLE',
#   'BRIGHT BLUES RIBBONS ',
#   'BUTTERFLIES STICKERS',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   "CHILDREN'S SPACEBOY MUG",
#   'CHILDRENS DOLLY GIRL MUG',
#   'CHOCOLATE BOX RIBBONS ',
#   'CIRCUS PARADE CHILDRENS EGG CUP ',
#   'CIRCUS PARADE LUNCH BOX ',
#   'DINOSAUR LUNCH BOX WITH CUTLERY',
#   'DOLLY GIRL CHILDRENS EGG CUP',
#   'FAIRY TALE COTTAGE NIGHTLIGHT',
#   'GUMBALL COAT RACK',
#   'GUMBALL MAGAZINE RACK',
#   'HOME SWEET HOME MUG',
#   'JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'KITTY PENCIL ERASERS',
#   'PARTY BUNTING',
#   'PARTY TIME PENCIL ERASERS',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SKULLS',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED BABY BUNTING ',
#   'RED GINGHAM ROSE JEWELLERY BOX',
#   'RED RETROSPOT MINI CASES',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'REGENCY CAKESTAND 3 TIER',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'ROMANTIC PINKS RIBBONS ',
#   'SET/3 RED GINGHAM ROSE STORAGE BOX',
#   'SET3 BOOK BOX GREEN GINGHAM FLOWER ',
#   'SLEEPING CAT ERASERS',
#   'SOLDIERS EGG CUP ',
#   'SPACEBOY CHILDRENS EGG CUP',
#   'SPACEBOY LUNCH BOX ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'WATERING CAN PINK BUNNY'],
#  ['CAKE PLATE LOVEBIRD PINK',
#   'CAKE PLATE LOVEBIRD WHITE',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'POSTAGE'],
#  ['MINI WOODEN HAPPY BIRTHDAY GARLAND', 'POSTAGE'],
#  ['FAIRY CAKE FLANNEL ASSORTED COLOUR',
#   'GROW YOUR OWN HERBS SET OF 3',
#   'OFFICE MUG WARMER BLACK+SILVER ',
#   'PASTEL COLOUR HONEYCOMB FAN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   "POPPY'S PLAYHOUSE LIVINGROOM ",
#   'POSTAGE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'REGENCY CAKESTAND 3 TIER',
#   'RETRO PLASTIC POLKA TRAY',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'TEA PARTY BIRTHDAY CARD',
#   'TOAST ITS - I LOVE YOU '],
#  ['10 COLOUR SPACEBOY PEN',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG SUKI  DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'POSTAGE',
#   'STRAWBERRY CHARLOTTE BAG',
#   'WOODLAND CHARLOTTE BAG'],
#  ['CAKE PLATE LOVEBIRD WHITE',
#   'CAKE STAND WHITE TWO TIER LACE',
#   'LOVE LARGE WOOD LETTERS ',
#   'RED RETROSPOT CAKE STAND',
#   'SET OF 72 RETROSPOT PAPER  DOILIES',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'SWEETHEART CERAMIC TRINKET BOX'],
#  ['CAKE STAND 3 TIER MAGIC GARDEN',
#   'CAKE STAND WHITE TWO TIER LACE',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'RED RETROSPOT CAKE STAND',
#   'SET/10 PINK POLKADOT PARTY CANDLES'],
#  [' SET 2 TEA TOWELS I LOVE LONDON ',
#   '60 CAKE CASES DOLLY GIRL DESIGN',
#   'AREA PATROLLED METAL SIGN',
#   'ASSORTED BOTTLE TOP  MAGNETS ',
#   'ASSORTED EASTER DECORATIONS  BELLS',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'CHOCOLATE THIS WAY METAL SIGN',
#   'DANISH ROSE DECORATIVE PLATE',
#   'DANISH ROSE DELUXE COASTER',
#   'DOORMAT UNION FLAG',
#   'DOORMAT UNION JACK GUNS AND ROSES',
#   'EMPIRE TISSUE BOX',
#   'FRIDGE MAGNETS US DINER ASSORTED',
#   'FRYING PAN UNION FLAG',
#   'HOME SWEET HOME METAL SIGN ',
#   'HOME SWEET HOME MUG',
#   'KINGS CHOICE MUG',
#   'KINGS CHOICE TEA CADDY ',
#   'KNITTED UNION FLAG HOT WATER BOTTLE',
#   'LARGE CAKE TOWEL PINK SPOTS',
#   'LONDON BUS COFFEE MUG',
#   'LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BOX I LOVE LONDON',
#   'MAGNETS PACK OF 4 CHILDHOOD MEMORY',
#   'MAGNETS PACK OF 4 SWALLOWS',
#   'METAL SIGN EMPIRE TEA',
#   'METAL SIGN NEIGHBOURHOOD WITCH ',
#   'METAL SIGN TAKE IT OR LEAVE IT ',
#   'MONEY BOX KINGS CHOICE DESIGN',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PAPERWEIGHT KINGS CHOICE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN VINTAGE PAISLEY ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'S/6 WOODEN SKITTLES IN COTTON BAG',
#   'SET 12 KIDS  WHITE CHALK STICKS',
#   'SET OF 12  VINTAGE POSTCARD SET',
#   'SET OF 6 VINTAGE NOTELETS KIT',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'SWISS ROLL TOWEL, CHOCOLATE  SPOTS',
#   'TOADSTOOL MONEY BOX',
#   'VINTAGE UNION JACK CUSHION COVER',
#   'WOODEN CROQUET GARDEN SET',
#   'WOODLAND CHARLOTTE BAG'],
#  ['12 PENCILS SMALL TUBE RED RETROSPOT',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'BOTTLE BAG RETROSPOT ',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'CHILDRENS APRON APPLES DESIGN',
#   'CIRCUS PARADE CHILDRENS EGG CUP ',
#   'CIRCUS PARADE LUNCH BOX ',
#   'COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'CUPCAKE LACE PAPER SET 6',
#   'CUTE CATS TAPE',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'JUMBO BAG TOYS ',
#   'LONDON BUS COFFEE MUG',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BOX I LOVE LONDON',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'PACK OF 6 BIRDY GIFT TAGS',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'PAPER BUNTING RETROSPOT',
#   'PINK  HONEYCOMB PAPER BALL ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'POMPOM CURTAIN',
#   'POSTAGE',
#   'QUEENS GUARD COFFEE MUG',
#   'RED  HARMONICA IN BOX ',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RED RETROSPOT CUP',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT TAPE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETROSPOT CHILDRENS APRON',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF 3 HEART COOKIE CUTTERS',
#   'SET OF 6 SOLDIER SKITTLES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SOLDIERS EGG CUP ',
#   'TABLECLOTH RED APPLES DESIGN ',
#   'WRAP RED APPLES '],
#  ['ASSORTED COLOUR MINI CASES',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'CARD HOLDER GINGHAM HEART',
#   'CERAMIC HEART FAIRY CAKE MONEY BANK',
#   'EDWARDIAN PARASOL RED',
#   'JUMBO BAG RED RETROSPOT',
#   'PINK BABY BUNTING',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT SHOPPING BAG',
#   'RED SPOTTY BISCUIT TIN'],
#  ['10 COLOUR SPACEBOY PEN',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'BLUE 3 PIECE POLKADOT CUTLERY SET',
#   'BLUE ROSE FABRIC MIRROR',
#   'CERAMIC STRAWBERRY CAKE MONEY BANK',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'FEATHER PEN,LIGHT PINK',
#   'FELTCRAFT CUSHION BUTTERFLY',
#   'FELTCRAFT DOLL EMILY',
#   'FELTCRAFT HAIRBANDS PINK AND WHITE ',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'JUMBO STORAGE BAG SUKI',
#   'LUNCH BAG RED RETROSPOT',
#   'MAKE YOUR OWN PLAYTIME CARD KIT',
#   'MINI PAINT SET VINTAGE ',
#   'MIRRORED WALL ART STARS',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'PINK CREAM FELT CRAFT TRINKET BOX ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SKULLS',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   "POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE BEDROOM ",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'POSTAGE',
#   'RED GINGHAM ROSE JEWELLERY BOX',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT TAPE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETRO PLASTIC ELEPHANT TRAY',
#   'RETRO PLASTIC POLKA TRAY',
#   'SPACEBOY BIRTHDAY CARD',
#   'WOODLAND  HEIGHT CHART STICKERS ',
#   'WORLD WAR 2 GLIDERS ASSTD DESIGNS'],
#  ['APPLE BATH SPONGE',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'CANDY SHOP  STICKER SHEET',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CIRCUS PARADE LUNCH BOX ',
#   'COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'OVEN MITT APPLES DESIGN',
#   'PARTY INVITES WOODLAND',
#   'POSTAGE',
#   'RED RETROSPOT CAKE STAND',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROBOT BIRTHDAY CARD',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'SANDWICH BATH SPONGE',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'SET/2 RED RETROSPOT TEA TOWELS ',
#   'SPACEBOY LUNCH BOX ',
#   'WRAP GREEN PEARS ',
#   'WRAP RED APPLES '],
#  ['BLACK RECORD COVER FRAME',
#   'CALENDAR PAPER CUT DESIGN',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'COFFEE MUG CAT + BIRD DESIGN',
#   'COFFEE MUG DOG + BALL DESIGN',
#   'FOLDING UMBRELLA RED/WHITE POLKADOT',
#   'IVORY DINER WALL CLOCK',
#   'LOVELY BONBON STICKER SHEET',
#   'LUNCH BOX I LOVE LONDON',
#   'OFFICE MUG WARMER CHOC+BLUE',
#   'OFFICE MUG WARMER PINK',
#   'OFFICE MUG WARMER POLKADOT',
#   'PACK OF 12 LONDON TISSUES ',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'PLASTERS IN TIN STRONGMAN',
#   'POSTAGE',
#   'RAINY LADIES BIRTHDAY CARD',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RED RETROSPOT CUP',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT UMBRELLA',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'SKULLS  WATER TRANSFER TATTOOS ',
#   'TABLECLOTH RED APPLES DESIGN ',
#   'TEA BAG PLATE RED RETROSPOT',
#   'UNION JACK FLAG PASSPORT COVER ',
#   'WOODLAND CHARLOTTE BAG',
#   'WOODLAND DESIGN  COTTON TOTE BAG'],
#  ['3 HOOK HANGER MAGIC GARDEN',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   'ALARM CLOCK BAKELIKE CHOCOLATE',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'BABUSHKA LIGHTS STRING OF 10',
#   'BATH BUILDING BLOCK WORD',
#   'CHARLOTTE BAG SUKI DESIGN',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'CHILDRENS DOLLY GIRL MUG',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CHILDS BREAKFAST SET SPACEBOY ',
#   'COFFEE MUG APPLES DESIGN',
#   'COWBOYS AND INDIANS BIRTHDAY CARD ',
#   'CROCHET ROSE PURSE WITH SUEDE BACK',
#   'DINOSAUR KEYRINGS ASSORTED',
#   'DOLLY GIRL LUNCH BOX',
#   'DOORMAT ENGLISH ROSE ',
#   'DOORMAT RED RETROSPOT',
#   'DOORMAT SPOTTY HOME SWEET HOME',
#   'ELEPHANT, BIRTHDAY CARD, ',
#   'FELTCRAFT DOLL EMILY',
#   'FELTCRAFT DOLL MARIA',
#   'FELTCRAFT DOLL ROSIE',
#   'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'FELTCRAFT PRINCESS OLIVIA DOLL',
#   'FLOWERS TILE HOOK',
#   'GLASS JAR PEACOCK BATH SALTS',
#   'HOLIDAY FUN LUDO',
#   'HOME BUILDING BLOCK WORD',
#   'HOME SWEET HOME METAL SIGN ',
#   'INFLATABLE POLITICAL GLOBE ',
#   'LA PALMIERA TILE HOOK',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG SUKI  DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'METAL SIGN HIS DINNER IS SERVED',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 20 SPACEBOY NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'PHOTO CUBE',
#   'PICTURE DOMINOES',
#   'PINK  HONEYCOMB PAPER BALL ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'PSYCHEDELIC TILE HOOK',
#   'RED  HARMONICA IN BOX ',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'ROUND SNACK BOXES SET OF 4 SKULLS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET OF 72 PINK HEART PAPER DOILIES',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SKULL LUNCH BOX WITH CUTLERY ',
#   'SPACEBOY BIRTHDAY CARD',
#   'SPACEBOY LUNCH BOX ',
#   'STRAWBERRY DREAM CHILDS UMBRELLA',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'VINTAGE BILLBOARD LOVE/HATE MUG',
#   'VINTAGE HEADS AND TAILS CARD GAME ',
#   'WELCOME  WOODEN BLOCK LETTERS'],
#  ['4 PINK DINNER CANDLE SILVER FLOCK',
#   'CAKE STAND WHITE TWO TIER LACE',
#   'EDWARDIAN PARASOL NATURAL',
#   'IVORY PILLAR CANDLE SILVER FLOCK',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PASTEL COLOUR HONEYCOMB FAN',
#   'PINK  HONEYCOMB PAPER BALL ',
#   'POSTAGE',
#   'SET 20 NAPKINS FAIRY CAKES DESIGN ',
#   'SET OF 72 PINK HEART PAPER DOILIES',
#   'VINTAGE CREAM 3 BASKET CAKE STAND',
#   'WOOD BLACK BOARD ANT WHITE FINISH'],
#  ['EASTER TIN BUNNY BOUQUET',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PAPER CHAIN KIT RETROSPOT',
#   'RED RETROSPOT MINI CASES',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'WOODLAND PARTY BAG + STICKER SET'],
#  ['POSTAGE'],
#  ['ANTIQUE GLASS DRESSING TABLE POT',
#   'ANTIQUE GLASS PEDESTAL BOWL',
#   'CREAM SWEETHEART EGG HOLDER',
#   'POSTAGE',
#   'RECIPE BOX PANTRY YELLOW DESIGN',
#   'SET OF 3 BUTTERFLY COOKIE CUTTERS',
#   'SET OF 3 CAKE TINS SKETCHBOOK',
#   'SOAP DISH BROCANTE',
#   'SWEETHEART WIRE WALL TIDY',
#   'WHITE BROCANTE SOAP DISH',
#   'WOODEN PICTURE FRAME WHITE FINISH'],
#  ['3 PIECE SPACEBOY COOKIE CUTTER SET',
#   '3 TRADITIONAl BISCUIT CUTTERS  SET',
#   'BALLOON WATER BOMB PACK OF 35',
#   'DINOSAUR KEYRINGS ASSORTED',
#   'HOLIDAY FUN LUDO',
#   'MAGIC DRAWING SLATE CIRCUS PARADE  ',
#   'MINI PAINT SET VINTAGE ',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'PACK OF 20 SPACEBOY NAPKINS',
#   'POSTAGE',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'SET OF 3 BUTTERFLY COOKIE CUTTERS',
#   'SET OF 3 HEART COOKIE CUTTERS',
#   'SET OF 6 T-LIGHTS CACTI ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'TRADITIONAL MODELLING CLAY',
#   'VINTAGE SNAKES & LADDERS'],
#  ['4 TRADITIONAL SPINNING TOPS',
#   'BINGO SET',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CHILDS BREAKFAST SET DOLLY GIRL ',
#   'CHILDS BREAKFAST SET SPACEBOY ',
#   "DOCTOR'S BAG SOFT TOY",
#   'HOLIDAY FUN LUDO',
#   "NURSE'S BAG SOFT TOY",
#   'PICNIC BASKET WICKER SMALL',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'TOOL BOX SOFT TOY ',
#   'VICTORIAN SEWING BOX SMALL ',
#   'WOODEN CROQUET GARDEN SET',
#   'WOODEN ROUNDERS GARDEN SET ',
#   'WOODLAND CHARLOTTE BAG'],
#  ['4 TRADITIONAL SPINNING TOPS',
#   'ASSORTED COLOUR BIRD ORNAMENT',
#   'BLACK/BLUE POLKADOT UMBRELLA',
#   'BLUE HARMONICA IN BOX ',
#   "CHILDREN'S APRON DOLLY GIRL ",
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'CLOTHES PEGS RETROSPOT PACK 24 ',
#   'DOLLY GIRL LUNCH BOX',
#   'DOORMAT ENGLISH ROSE ',
#   'DOORMAT NEIGHBOURHOOD WITCH ',
#   'DOORMAT NEW ENGLAND',
#   'DOORMAT SPOTTY HOME SWEET HOME',
#   'INFLATABLE POLITICAL GLOBE ',
#   'LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'MAGNETS PACK OF 4 SWALLOWS',
#   'MAGNETS PACK OF 4 VINTAGE COLLAGE',
#   'MINI JIGSAW CIRCUS PARADE ',
#   'MINI JIGSAW SPACEBOY',
#   'MINI LADLE LOVE HEART RED ',
#   'MINI PAINT SET VINTAGE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN VINTAGE PAISLEY ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   "POPPY'S PLAYHOUSE BEDROOM ",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   "POPPY'S PLAYHOUSE LIVINGROOM ",
#   'RED  HARMONICA IN BOX ',
#   'RED HEART SHAPE LOVE BUCKET ',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT SMALL MILK JUG',
#   'RED RETROSPOT TRADITIONAL TEAPOT ',
#   'RED RETROSPOT UMBRELLA',
#   'RETROSPOT CHILDRENS APRON',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'ROSES REGENCY TEACUP AND SAUCER ',
#   'SEASIDE FLYING DISC',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'SKULL DESIGN TV DINNER TRAY',
#   'SPACEBOY BIRTHDAY CARD',
#   'SPACEBOY LUNCH BOX ',
#   'SPACEBOY TV DINNER TRAY',
#   'TRADITIONAL MODELLING CLAY',
#   'TV DINNER TRAY DOLLY GIRL'],
#  ['4 TRADITIONAL SPINNING TOPS',
#   'BOOM BOX SPEAKER BOYS',
#   'CIRCUS PARADE CHILDRENS EGG CUP ',
#   'CIRCUS PARADE LUNCH BOX ',
#   'COFFEE MUG DOG + BALL DESIGN',
#   'GUMBALL COAT RACK',
#   'INFLATABLE POLITICAL GLOBE ',
#   'MEASURING TAPE BABUSHKA PINK',
#   'OFFICE MUG WARMER CHOC+BLUE',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'POSTAGE',
#   'RED RETROSPOT CUP',
#   'RED RETROSPOT MINI CASES',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/4 SKULL BADGES',
#   'TEA PARTY BIRTHDAY CARD',
#   'TRAVEL SEWING KIT'],
#  ['5 HOOK HANGER MAGIC TOADSTOOL',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   '6 RIBBONS RUSTIC CHARM',
#   'BAKING MOULD CHOCOLATE CUPCAKES',
#   'DOLLY GIRL LUNCH BOX',
#   'EASTER TIN BUNNY BOUQUET',
#   'EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL NATURAL',
#   'EDWARDIAN PARASOL RED',
#   'JAM MAKING SET PRINTED',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'LUNCH BAG PINK POLKADOT',
#   'LUNCH BAG SUKI  DESIGN ',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE',
#   'RED RETROSPOT PICNIC BAG',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'REGENCY CAKESTAND 3 TIER',
#   'TABLECLOTH RED APPLES DESIGN '],
#  ['ASSORTED BOTTLE TOP  MAGNETS ',
#   'CIRCUS PARADE CHILDRENS EGG CUP ',
#   'EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL NATURAL',
#   'EDWARDIAN PARASOL RED',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'LUNCH BAG PINK POLKADOT',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT UMBRELLA',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'SKULL LUNCH BOX WITH CUTLERY ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'],
#  ['CHARLOTTE BAG PINK POLKADOT',
#   'FOOD/DRINK SPONGE STICKERS',
#   'GROW A FLYTRAP OR SUNFLOWER IN TIN',
#   'PARTY INVITES SPACEMAN',
#   'POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'TEA PARTY BIRTHDAY CARD',
#   'WORLD WAR 2 GLIDERS ASSTD DESIGNS'],
#  ['4 TRADITIONAL SPINNING TOPS',
#   '6 RIBBONS RUSTIC CHARM',
#   'ALARM CLOCK BAKELIKE CHOCOLATE',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'ASSORTED COLOURS SILK FAN',
#   'ASSORTED EASTER GIFT TAGS',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'BAKING SET SPACEBOY DESIGN',
#   'BASKET OF TOADSTOOLS',
#   'BLACK/BLUE POLKADOT UMBRELLA',
#   'BLUE HARMONICA IN BOX ',
#   'BOYS VINTAGE TIN SEASIDE BUCKET',
#   'BRIGHT BLUES RIBBONS ',
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'CLOTHES PEGS RETROSPOT PACK 24 ',
#   'COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'CUPCAKE LACE PAPER SET 6',
#   'CURIOUS IMAGES GIFT WRAP SET',
#   'EASTER TIN CHICKS IN GARDEN',
#   'EASTER TIN KEEPSAKE',
#   'GIRLS VINTAGE TIN SEASIDE BUCKET',
#   'GLASS JAR DAISY FRESH COTTON WOOL',
#   'JAM JAR WITH GREEN LID',
#   'JAM JAR WITH PINK LID',
#   'JAM MAKING SET PRINTED',
#   'JAM MAKING SET WITH JARS',
#   'LARGE RED RETROSPOT WINDMILL',
#   'LOVE HEART SOCK HANGER',
#   'LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'MAGIC SHEEP WOOL GROWING FROM PAPER',
#   'MINI PAINT SET VINTAGE ',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 SPACEBOY NAPKINS',
#   'PACK OF 60 SPACEBOY CAKE CASES',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PAPER BUNTING RETROSPOT',
#   'POSTAGE',
#   'RED  HARMONICA IN BOX ',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT LUGGAGE TAG',
#   'RED RETROSPOT PICNIC BAG',
#   'RED RETROSPOT SHOPPING BAG',
#   'RED RETROSPOT UMBRELLA',
#   'RED SPOTTY BISCUIT TIN',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETROSPOT CHILDRENS APRON',
#   'ROSES REGENCY TEACUP AND SAUCER ',
#   'SET OF 3 CAKE TINS PANTRY DESIGN ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SMALL RED RETROSPOT WINDMILL',
#   'SMALL SILVER TRELLIS CANDLEPOT',
#   'STRAWBERRY DREAM CHILDS UMBRELLA',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TUMBLER, NEW ENGLAND'],
#  ['12 PENCILS SMALL TUBE RED RETROSPOT',
#   'MINI JIGSAW CIRCUS PARADE ',
#   'MINI JIGSAW SPACEBOY',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PAPER BUNTING RETROSPOT',
#   'PINK POLKADOT BOWL',
#   'POSTAGE',
#   'RED RETROSPOT BOWL',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SMALL RED RETROSPOT WINDMILL'],
#  ['ASSORTED COLOUR MINI CASES',
#   'ASSORTED EASTER GIFT TAGS',
#   'CHILDS GARDEN TROWEL BLUE ',
#   'CHILDS GARDEN TROWEL PINK',
#   'EASTER TIN BUNNY BOUQUET',
#   'EDWARDIAN PARASOL NATURAL',
#   'FAIRY TALE COTTAGE NIGHTLIGHT',
#   'FELT TOADSTOOL LARGE',
#   'JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'LARGE RED RETROSPOT WINDMILL',
#   'MINI PAINT SET VINTAGE ',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED RETROSPOT BIG BOWL',
#   'RED RETROSPOT BOWL',
#   'RED RETROSPOT PICNIC BAG',
#   'RED RETROSPOT PLATE ',
#   'RED RETROSPOT ROUND CAKE TINS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SMALL RED RETROSPOT WINDMILL',
#   'WHEELBARROW FOR CHILDREN ',
#   'WRAP ALPHABET DESIGN',
#   'WRAP VINTAGE PETALS  DESIGN'],
#  ['CARTOON  PENCIL SHARPENERS',
#   'MINI JIGSAW CIRCUS PARADE ',
#   'MINI JIGSAW DOLLY GIRL',
#   'MINI PAINT SET VINTAGE ',
#   'PACK OF 12 CIRCUS PARADE TISSUES ',
#   'PACK OF 12 LONDON TISSUES ',
#   'PACK OF 12 SPACEBOY TISSUES',
#   'PACK OF 12 WOODLAND TISSUES ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '],
#  ['12 PENCILS TALL TUBE RED RETROSPOT',
#   '12 PENCILS TALL TUBE WOODLAND',
#   'LUNCH BOX I LOVE LONDON',
#   'PICNIC BOXES SET OF 3 RETROSPOT ',
#   'PICTURE DOMINOES',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '],
#  ['10 COLOUR SPACEBOY PEN',
#   '12 COLOURED PARTY BALLOONS',
#   '12 PENCILS SMALL TUBE RED RETROSPOT',
#   '12 PENCILS SMALL TUBE SKULL',
#   '4 TRADITIONAL SPINNING TOPS',
#   'BAG 125g SWIRLY MARBLES',
#   'BALLOON PUMP WITH 10 BALLOONS',
#   'CERAMIC PIRATE CHEST MONEY BANK',
#   'CHILDS GARDEN FORK BLUE ',
#   'CHILDS GARDEN FORK PINK',
#   'CHILDS GARDEN TROWEL BLUE ',
#   'CHILDS GARDEN TROWEL PINK',
#   'DINOSAUR PARTY BAG + STICKER SET',
#   'FANCY FONT BIRTHDAY CARD, ',
#   'MINI JIGSAW DOLLY GIRL',
#   'MINI JIGSAW SPACEBOY',
#   'MINI PAINT SET VINTAGE ',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'PARTY INVITES DINOSAURS',
#   'PARTY INVITES JAZZ HEARTS',
#   'PARTY INVITES SPACEMAN',
#   'PINK PARTY BAGS',
#   'PLASTERS IN TIN SKULLS',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN VINTAGE PAISLEY ',
#   "POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'S/6 WOODEN SKITTLES IN COTTON BAG',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/4 SKULL BADGES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SKULL LUNCH BOX WITH CUTLERY ',
#   'SKULLS  WATER TRANSFER TATTOOS ',
#   'SKULLS PARTY BAG + STICKER SET',
#   'SPACEBOY BIRTHDAY CARD',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TEA PARTY BIRTHDAY CARD',
#   'TOAST ITS - BEST MUM',
#   'TRADITIONAL KNITTING NANCY',
#   'TRADITIONAL WOODEN SKIPPING ROPE',
#   'WOOD STAMP SET HAPPY BIRTHDAY'],
#  ['BLUE 3 PIECE POLKADOT CUTLERY SET',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'JUMBO STORAGE BAG SUKI',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SUKI  DESIGN ',
#   'PINK LOVE BIRD CANDLE',
#   'POSTAGE',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'RED RETROSPOT CAKE STAND',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RED RETROSPOT PICNIC BAG',
#   'SET/6 FROG PRINCE T-LIGHT CANDLES',
#   'SET/6 PINK BIRD T-LIGHT CANDLES',
#   'STRAWBERRY   PICNIC BAG'],
#  ['20 DOLLY PEGS RETROSPOT',
#   'BALLOONS  WRITING SET ',
#   'CAKE STAND 3 TIER MAGIC GARDEN',
#   'CALENDAR PAPER CUT DESIGN',
#   "CHILDREN'S APRON DOLLY GIRL ",
#   'CHILDRENS APRON APPLES DESIGN',
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'CHINESE DRAGON PAPER LANTERNS',
#   'DANISH ROSE DELUXE COASTER',
#   "DOLLY MIXTURE CHILDREN'S UMBRELLA",
#   'DOORMAT RED RETROSPOT',
#   'DOORMAT RESPECTABLE HOUSE',
#   'DOORMAT SPOTTY HOME SWEET HOME',
#   'FAIRY TALE COTTAGE NIGHTLIGHT',
#   'FUNKY DIVA PEN',
#   'ILLUSTRATED CAT BOWL ',
#   'ORANGE VOTIVE CANDLE',
#   'PACK OF 12 CIRCUS PARADE TISSUES ',
#   'PACK OF 12 HEARTS DESIGN TISSUES ',
#   'PACK OF 12 RED RETROSPOT TISSUES ',
#   'PACK OF 12 SPACEBOY TISSUES',
#   'PACK OF 12 SUKI TISSUES ',
#   'PACK OF 12 WOODLAND TISSUES ',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'PIGGY BANK RETROSPOT ',
#   'PINK NEW BAROQUECANDLESTICK CANDLE',
#   'PINK POLKADOT BOWL',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'POLKADOT PEN',
#   'POSTAGE',
#   'RED  HARMONICA IN BOX ',
#   'RED RETROSPOT APRON ',
#   'RED RETROSPOT BIG BOWL',
#   'RED RETROSPOT BOWL',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT OVEN GLOVE ',
#   'RED RETROSPOT PURSE ',
#   'RED RETROSPOT TEA CUP AND SAUCER ',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'S/4 PINK FLOWER CANDLES IN BOWL',
#   'SET OF 6 GIRLS CELEBRATION CANDLES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/20 STRAWBERRY PAPER NAPKINS ',
#   'SET/4 RED MINI ROSE CANDLE IN BOWL',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SPACEBOY BIRTHDAY CARD',
#   'STANDING FAIRY POLE SUPPORT ',
#   'STRAWBERRY DREAM CHILDS UMBRELLA',
#   'STRAWBRY SCENTED VOTIVE CANDLE',
#   'TEA BAG PLATE RED RETROSPOT'],
#  ['RETRO PLASTIC POLKA TRAY'],
#  [' SET 2 TEA TOWELS I LOVE LONDON ',
#   'BOX OF VINTAGE JIGSAW BLOCKS ',
#   'CARD I LOVE LONDON ',
#   'CHILDRENS GARDEN GLOVES BLUE',
#   'CHILDRENS GARDEN GLOVES PINK',
#   'CHILDS GARDEN BRUSH BLUE',
#   'CHILDS GARDEN BRUSH PINK',
#   'CHILDS GARDEN FORK BLUE ',
#   'CHILDS GARDEN FORK PINK',
#   'CHILDS GARDEN RAKE BLUE',
#   'CHILDS GARDEN RAKE PINK',
#   'CHILDS GARDEN SPADE BLUE',
#   'CHILDS GARDEN SPADE PINK',
#   'CHILDS GARDEN TROWEL BLUE ',
#   'CHILDS GARDEN TROWEL PINK',
#   'DAIRY MAID TRADITIONAL TEAPOT ',
#   'FRIDGE MAGNETS US DINER ASSORTED',
#   'FULL ENGLISH BREAKFAST PLATE',
#   'HOMEMADE JAM SCENTED CANDLES',
#   'LONDON BUS COFFEE MUG',
#   'LUNCH BOX I LOVE LONDON',
#   'PAPER CHAIN KIT EMPIRE',
#   'QUEENS GUARD COFFEE MUG',
#   'RAINY LADIES BIRTHDAY CARD',
#   'RED RETROSPOT TRADITIONAL TEAPOT ',
#   'RETRO COFFEE MUGS ASSORTED',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'ROBOT BIRTHDAY CARD',
#   'SET OF 6 SOLDIER SKITTLES',
#   'TEA FOR ONE POLKADOT',
#   'WOODEN CROQUET GARDEN SET',
#   'WOODEN ROUNDERS GARDEN SET ',
#   'WOODEN SKITTLES GARDEN SET'],
#  ['12 EGG HOUSE PAINTED WOOD',
#   'ASSORTED EASTER GIFT TAGS',
#   'EASTER TIN CHICKS IN GARDEN',
#   'POSTAGE',
#   'RETROSPOT PADDED SEAT CUSHION',
#   'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#   'TEA FOR ONE POLKADOT',
#   'WRAP DOILEY DESIGN'],
#  ['CAKE STAND WHITE TWO TIER LACE',
#   'CARD BIRTHDAY COWBOY',
#   'CARD CIRCUS PARADE',
#   'COWBOYS AND INDIANS BIRTHDAY CARD ',
#   'GROW A FLYTRAP OR SUNFLOWER IN TIN',
#   'MINI PAINT SET VINTAGE ',
#   'MULTICOLOUR HONEYCOMB FAN',
#   'PASTEL COLOUR HONEYCOMB FAN',
#   'PINK LOVE HEART SHAPE CUP',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE',
#   'RED LOVE HEART SHAPE CUP',
#   'RED RETROSPOT BOWL',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'SMALL POPCORN HOLDER',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'],
#  ['LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'MINI CAKE STAND T-LIGHT HOLDER',
#   'SET OF 3 BUTTERFLY COOKIE CUTTERS',
#   'SET/10 RED POLKADOT PARTY CANDLES'],
#  ['3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'POSTAGE',
#   'RED RETROSPOT BOWL',
#   'SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES'],
#  ['3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'MINI CAKE STAND T-LIGHT HOLDER',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'PACK OF 60 PINK PAISLEY CAKE CASES',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'POSTAGE',
#   'RED RETROSPOT SMALL MILK JUG',
#   'RED RETROSPOT STORAGE JAR',
#   'RIBBON REEL CHRISTMAS PRESENT ',
#   'RIBBON REEL CHRISTMAS SOCK BAUBLE',
#   'RIBBON REEL MAKING SNOWMEN ',
#   'SET OF 20 KIDS COOKIE CUTTERS'],
#  ['BIG DOUGHNUT FRIDGE MAGNETS',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   "CHILDREN'S APRON DOLLY GIRL ",
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'COFFEE MUG APPLES DESIGN',
#   'DOLLY GIRL LUNCH BOX',
#   'DOORMAT AIRMAIL ',
#   'DOORMAT I LOVE LONDON',
#   'DOORMAT UNION FLAG',
#   'LONDON BUS COFFEE MUG',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BOX I LOVE LONDON',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'MINI JIGSAW DOLLY GIRL',
#   'MINI JIGSAW SPACEBOY',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RED RETROSPOT PURSE ',
#   'SNOWSTORM PHOTO FRAME FRIDGE MAGNET',
#   'SPACEBOY LUNCH BOX ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TOTE BAG I LOVE LONDON'],
#  ['CHILDRENS CUTLERY POLKADOT BLUE',
#   'CHILDRENS CUTLERY RETROSPOT RED ',
#   'GUMBALL COAT RACK',
#   'GUMBALL MAGAZINE RACK',
#   'JAM MAKING SET PRINTED',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   "POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT PLATE ',
# ...
#   'ALARM CLOCK BAKELIKE RED ',
#   'ASSORTED COLOUR MINI CASES',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'BAKING SET SPACEBOY DESIGN',
#   'CARTOON  PENCIL SHARPENERS',
#   'FAIRY TALE COTTAGE NIGHT LIGHT',
#   'GREEN METAL BOX ARMY SUPPLIES',
#   'ICE CREAM BUBBLES',
#   'LUNCH BOX I LOVE LONDON',
#   'MAGIC DRAWING SLATE DOLLY GIRL ',
#   'MAGIC DRAWING SLATE SPACEBOY ',
#   'MINI PAINT SET VINTAGE ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SKULLS',
#   'PLASTERS IN TIN VINTAGE PAISLEY ',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED METAL BOX TOP SECRET',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'WOODLAND BUNNIES LOLLY MAKERS'],
#  ['COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'MINI LIGHTS WOODLAND MUSHROOMS',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN STRONGMAN',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED APPLES CHOPPING BOARD   ',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   "ROLL WRAP 50'S CHRISTMAS",
#   "ROLL WRAP 50'S RED CHRISTMAS ",
#   'ROLL WRAP VINTAGE CHRISTMAS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '],
#  ['36 PENCILS TUBE RED RETROSPOT',
#   'ASSORTED COLOUR MINI CASES',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'BLUE SCOTTIE DOG W FLOWER PATTERN',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   "CHILDREN'S APRON DOLLY GIRL ",
#   'COLOURING PENCILS BROWN TUBE',
#   'GIRAFFE WOODEN RULER',
#   'MAKE YOUR OWN FLOWERPOWER CARD KIT',
#   'PINK FAIRY CAKE CHILDRENS APRON',
#   'PINK OWL SOFT TOY',
#   'PINK SCOTTIE DOG W FLOWER PATTERN',
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT PICNIC BAG',
#   'RETROSPOT CHILDRENS APRON',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'REVOLVER WOODEN RULER ',
#   'SET 12 COLOUR PENCILS LOVE LONDON',
#   'SET 36 COLOUR PENCILS DOLLY GIRL',
#   'SET 36 COLOUR PENCILS SPACEBOY ',
#   'SET 36 COLOURING PENCILS DOILY',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'SMALL RED BABUSHKA NOTEBOOK ',
#   'SMALL YELLOW BABUSHKA NOTEBOOK '],
#  ['60 TEATIME FAIRY CAKE CASES',
#   'FAIRY CAKES NOTEBOOK A6 SIZE',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'REGENCY CAKESTAND 3 TIER',
#   'SET OF 60 VINTAGE LEAF CAKE CASES ',
#   'SET OF 72 RETROSPOT PAPER  DOILIES',
#   'SNACK TRAY PAISLEY PARK',
#   'SNACK TRAY RED GINGHAM',
#   'SNACK TRAY RED VINTAGE DOILY',
#   'VINTAGE DOILY TRAVEL SEWING KIT',
#   'VINTAGE LEAF MAGNETIC NOTEPAD'],
#  ['6 GIFT TAGS VINTAGE CHRISTMAS ',
#   'DOILY THANK YOU CARD',
#   'EDWARDIAN PARASOL NATURAL',
#   'JAM MAKING SET PRINTED',
#   "JUMBO BAG 50'S CHRISTMAS ",
#   'JUMBO BAG VINTAGE CHRISTMAS ',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG RED VINTAGE DOILY',
#   'LUNCH BAG VINTAGE DOILY ',
#   'LUNCH BAG VINTAGE LEAF DESIGN',
#   'MINI LIGHTS WOODLAND MUSHROOMS',
#   "PAPER CHAIN KIT 50'S CHRISTMAS ",
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RIBBON REEL CHRISTMAS SOCK BAUBLE',
#   'SET OF 4 KNICK KNACK TINS DOILY ',
#   'SET OF 4 KNICK KNACK TINS LEAF',
#   'TEA PARTY BIRTHDAY CARD'],
#  ['12 COLOURED PARTY BALLOONS',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'BAKING SET SPACEBOY DESIGN',
#   'BLUE HARMONICA IN BOX ',
#   'BLUE POLKADOT BOWL',
#   'BOX OF 6 CHRISTMAS CAKE DECORATIONS',
#   'CARD CHRISTMAS VILLAGE',
#   'CARD MOTORBIKE SANTA',
#   "CHILDREN'S APRON DOLLY GIRL ",
#   'CHILDRENS CUTLERY CIRCUS PARADE',
#   'CHILDRENS CUTLERY DOLLY GIRL ',
#   'CHILDRENS CUTLERY POLKADOT PINK',
#   'CHILDRENS CUTLERY SPACEBOY ',
#   'CHILDS BREAKFAST SET DOLLY GIRL ',
#   'CHILDS BREAKFAST SET SPACEBOY ',
#   'CHRISTMAS GINGHAM STAR',
#   'CHRISTMAS GINGHAM TREE',
#   'CHRISTMAS RETROSPOT ANGEL WOOD',
#   'CHRISTMAS RETROSPOT TREE WOOD',
#   'CLOTHES PEGS RETROSPOT PACK 24 ',
#   'EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL RED',
#   'ENGLISH ROSE HOT WATER BOTTLE',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'GINGHAM HEART DECORATION',
#   'GREY HEART HOT WATER BOTTLE',
#   'HEART WOODEN CHRISTMAS DECORATION',
#   'LARGE PURPLE BABUSHKA NOTEBOOK  ',
#   'LARGE RED BABUSHKA NOTEBOOK ',
#   'LARGE YELLOW BABUSHKA NOTEBOOK ',
#   'LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG PAISLEY PARK  ',
#   'LUNCH BAG RED VINTAGE DOILY',
#   'LUNCH BAG VINTAGE DOILY ',
#   'MAGNETS PACK OF 4 HOME SWEET HOME',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'MAGNETS PACK OF 4 SWALLOWS',
#   'MAGNETS PACK OF 4 VINTAGE COLLAGE',
#   'MAGNETS PACK OF 4 VINTAGE LABELS ',
#   'MINI PLAYING CARDS BUFFALO BILL ',
#   'MINI PLAYING CARDS GYMKHANA',
#   'PINK POLKADOT BOWL',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED RETROSPOT BOWL',
#   'RED ROCKING HORSE HAND PAINTED',
#   'RETROSPOT WOODEN HEART DECORATION',
#   'ROCKING HORSE RED CHRISTMAS ',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'SET OF 3 WOODEN SLEIGH DECORATIONS',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SMALL HANGING IVORY/RED WOOD BIRD',
#   'SMALL PURPLE BABUSHKA NOTEBOOK ',
#   'SMALL RED BABUSHKA NOTEBOOK ',
#   'SMALL YELLOW BABUSHKA NOTEBOOK ',
#   'SWALLOW WOODEN CHRISTMAS DECORATION',
#   'TEA BAG PLATE RED RETROSPOT',
#   'VINTAGE CHRISTMAS STOCKING ',
#   'WHITE ROCKING HORSE HAND PAINTED',
#   'WOODEN STAR CHRISTMAS SCANDINAVIAN',
#   'WOODLAND LARGE BLUE FELT HEART',
#   'WOODLAND LARGE PINK FELT HEART',
#   'WOODLAND LARGE RED FELT HEART',
#   'WOODLAND SMALL BLUE FELT HEART',
#   'WOODLAND SMALL PINK FELT HEART',
#   'WOODLAND SMALL RED FELT HEART'],
#  ['CHERRY BLOSSOM  DECORATIVE FLASK',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CHILDS BREAKFAST SET SPACEBOY ',
#   'DOORMAT FANCY FONT HOME SWEET HOME',
#   'DOORMAT VINTAGE LEAF',
#   'HOMEMADE JAM SCENTED CANDLES',
#   'JAM MAKING SET WITH JARS',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'REGENCY CAKESTAND 3 TIER',
#   'SAVE THE PLANET COTTON TOTE BAG'],
#  ['CHARLOTTE BAG SUKI DESIGN',
#   'DOLLY GIRL MINI BACKPACK',
#   'FEATHER PEN,LIGHT PINK',
#   'JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'LIPSTICK PEN RED',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'SET OF 9 HEART SHAPED BALLOONS'],
#  [" 50'S CHRISTMAS GIFT BAG LARGE",
#   "6 GIFT TAGS 50'S CHRISTMAS ",
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   "BOX OF 6 MINI 50'S CRACKERS",
#   'BOX OF 6 MINI VINTAGE CRACKERS',
#   "CHILDREN'S SPACEBOY MUG",
#   'CHILDRENS DOLLY GIRL MUG',
#   'COFFEE MUG CAT + BIRD DESIGN',
#   'GIFT BAG PSYCHEDELIC APPLES',
#   'ICE CREAM SUNDAE LIP GLOSS',
#   'LONDON BUS COFFEE MUG',
#   'LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG WOODLAND',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'ROLL WRAP VINTAGE CHRISTMAS',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'VINTAGE DOILY DELUXE SEWING KIT ',
#   'VINTAGE DOILY TRAVEL SEWING KIT',
#   'WRAP RED VINTAGE DOILY'],
#  ['4 TRADITIONAL SPINNING TOPS',
#   'ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SKULLS',
#   'PLASTERS IN TIN VINTAGE PAISLEY ',
#   'POSTAGE'],
#  [' DOLLY GIRL BEAKER',
#   'ALARM CLOCK BAKELIKE CHOCOLATE',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE IVORY',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'BLUE HARMONICA IN BOX ',
#   'BUNDLE OF 3 ALPHABET EXERCISE BOOKS',
#   'BUNDLE OF 3 RETRO NOTE BOOKS',
#   'CERAMIC STRAWBERRY CAKE MONEY BANK',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'CHILDRENS APRON APPLES DESIGN',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CHILDS BREAKFAST SET DOLLY GIRL ',
#   'COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG CAT + BIRD DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'DINOSAUR LUNCH BOX WITH CUTLERY',
#   "JUMBO BAG 50'S CHRISTMAS ",
#   'JUMBO BAG STRAWBERRY',
#   'JUMBO BAG VINTAGE CHRISTMAS ',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'MAGNETS PACK OF 4 CHILDHOOD MEMORY',
#   'MAGNETS PACK OF 4 HOME SWEET HOME',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'MAGNETS PACK OF 4 SWALLOWS',
#   'MAGNETS PACK OF 4 VINTAGE COLLAGE',
#   'MINI LIGHTS WOODLAND MUSHROOMS',
#   'MINI PLAYING CARDS DOLLY GIRL ',
#   'PANTRY MAGNETIC  SHOPPING LIST',
#   'PARTY BUNTING',
#   'PIG KEYRING WITH LIGHT & SOUND ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SKULLS',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN VINTAGE PAISLEY ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RECYCLING BAG RETROSPOT ',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETROSPOT CHILDRENS APRON',
#   'ROUND STORAGE TIN VINTAGE LEAF',
#   'SILVER MUG BONE CHINA TREE OF LIFE',
#   'SKULL LUNCH BOX WITH CUTLERY ',
#   'SKULLS  WATER TRANSFER TATTOOS ',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPOTTY BUNTING',
#   'STORAGE TIN VINTAGE LEAF',
#   'STRAWBERRY CHARLOTTE BAG',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'TRADITIONAL NAUGHTS & CROSSES',
#   'VINTAGE DOILY JUMBO BAG RED ',
#   'WOODEN SCHOOL COLOURING SET'],
#  ['DOORMAT KEEP CALM AND COME IN',
#   'KINGS CHOICE BISCUIT TIN',
#   'MINT GREEN ROSE TOWEL'],
#  ['60 CAKE CASES DOLLY GIRL DESIGN',
#   'AIRLINE BAG VINTAGE JET SET WHITE',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   'BLACK ENAMEL FLOWER RING',
#   'BLUE HARMONICA IN BOX ',
#   'DOUGHNUT LIP GLOSS ',
#   'ENGLISH ROSE SMALL SCENTED FLOWER',
#   'LANDMARK FRAME COVENT GARDEN ',
#   'LOVE HOT WATER BOTTLE',
#   'MOUSE TOY WITH PINK T-SHIRT',
#   'PICTURE DOMINOES',
#   'PLAYING CARDS JUBILEE UNION JACK',
#   'POSTAGE',
#   'SCOTTIE DOG HOT WATER BOTTLE',
#   'SET 12 COLOUR PENCILS DOLLY GIRL ',
#   'SET 12 COLOUR PENCILS SPACEBOY ',
#   'SET 12 COLOURING PENCILS DOILY',
#   'TRADITIONAL WOODEN CATCH CUP GAME ',
#   'VINTAGE HEADS AND TAILS CARD GAME ',
#   'VINTAGE SNAP CARDS',
#   'VINTAGE UNION JACK MEMOBOARD'],
#  ['JUMBO  BAG BAROQUE BLACK WHITE',
#   'JUMBO BAG APPLES',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'MINI LIGHTS WOODLAND MUSHROOMS',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'TRADTIONAL ALPHABET STAMP SET'],
#  ['CHARLOTTE BAG APPLES DESIGN',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'CHILDRENS APRON APPLES DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'CUTE CATS TAPE',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   "JUMBO BAG 50'S CHRISTMAS ",
#   'JUMBO BAG APPLES',
#   'JUMBO BAG VINTAGE DOILY ',
#   'JUMBO BAG VINTAGE LEAF',
#   'PAPER BUNTING RETROSPOT',
#   'PICNIC BOXES SET OF 3 RETROSPOT ',
#   'POSTAGE',
#   'RECYCLING BAG RETROSPOT ',
#   'RED APPLES CHOPPING BOARD   ',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT TAPE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETROSPOT CHILDRENS APRON',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'SET OF 6 SOLDIER SKITTLES',
#   'TOY TIDY PINK POLKADOT',
#   'WOODLAND CHARLOTTE BAG',
#   "WRAP 50'S  CHRISTMAS",
#   'WRAP RED APPLES '],
#  ['BLACK KITCHEN SCALES',
#   'CARD MOTORBIKE SANTA',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   "CHILDREN'S SPACEBOY MUG",
#   'CHILDRENS CUTLERY POLKADOT BLUE',
#   'CHILDRENS CUTLERY POLKADOT PINK',
#   'CHILDRENS CUTLERY RETROSPOT RED ',
#   'COFFEE MUG APPLES DESIGN',
#   'IVORY KITCHEN SCALES',
#   'MINT KITCHEN SCALES',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'PAPER BUNTING RETROSPOT',
#   'POSTAGE',
#   'RED KITCHEN SCALES',
#   'RED RETROSPOT OVEN GLOVE ',
#   "ROLL WRAP 50'S CHRISTMAS",
#   'ROLL WRAP VINTAGE CHRISTMAS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'SET OF 12 FAIRY CAKE BAKING CASES',
#   'SET OF 12 MINI LOAF BAKING CASES',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF 3 REGENCY CAKE TINS',
#   'SET OF 5 MINI GROCERY MAGNETS',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'SET/2 RED RETROSPOT TEA TOWELS ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'STORAGE TIN VINTAGE DOILY ',
#   'VINTAGE RED TRIM ENAMEL BOWL ',
#   'WRAP  VINTAGE DOILY '],
#  ['POSTAGE'],
#  ['CHILDRENS APRON SPACEBOY DESIGN',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG CAT + BIRD DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'FOLDING UMBRELLA BLACKBLUE POLKADOT',
#   'FOLDING UMBRELLA RED/WHITE POLKADOT',
#   'FRIDGE MAGNETS LA VIE EN ROSE',
#   'FRIDGE MAGNETS LES ENFANTS ASSORTED',
#   'PARTY BUNTING',
#   'PENS ASSORTED FUNNY FACE',
#   'PLAYING CARDS I LOVE LONDON ',
#   'POSTAGE',
#   'RED APPLES CHOPPING BOARD   ',
#   'RED ENCHANTED FOREST PLACEMAT',
#   'RED RETROSPOT BOWL',
#   'RETRO PLASTIC ELEPHANT TRAY',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET OF 3 REGENCY CAKE TINS',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SNACK TRAY HAPPY FOREST  ',
#   'TRADITIONAL PICK UP STICKS GAME ',
#   'WATERING CAN BLUE ELEPHANT'],
#  ['BAKING SET 9 PIECE RETROSPOT ',
#   'BLUE POLKADOT CUP',
#   'BUNDLE OF 3 ALPHABET EXERCISE BOOKS',
#   'CHRISTMAS STAR WISH LIST CHALKBOARD',
#   'DOORMAT FAIRY CAKE',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'GLASS  SONGBIRD STORAGE JAR',
#   'GUMBALL COAT RACK',
#   'JUMBO BAG RED RETROSPOT',
#   'JUMBO STORAGE BAG SUKI',
#   'NATURAL SLATE CHALKBOARD LARGE ',
#   'OPEN CLOSED METAL SIGN',
#   'PACK OF 60 PINK PAISLEY CAKE CASES',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PAPER LANTERN 9 POINT SNOW STAR ',
#   'PARTY BUNTING',
#   'PINK  POLKADOT CUP',
#   'PINK POLKADOT PLATE ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT PLATE ',
#   'REGENCY CAKESTAND 3 TIER',
#   'REGENCY SUGAR TONGS',
#   'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'SET OF 3 HEART COOKIE CUTTERS'],
#  ['4 IVORY DINNER CANDLES SILVER FLOCK',
#   'CHILDRENS CUTLERY CIRCUS PARADE',
#   'CHILDRENS CUTLERY DOLLY GIRL ',
#   'CHILDRENS CUTLERY SPACEBOY ',
#   'POSTAGE'],
#  ['CARD I LOVE LONDON ',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'LARGE PURPLE BABUSHKA NOTEBOOK  ',
#   'LARGE RED BABUSHKA NOTEBOOK ',
#   'LARGE YELLOW BABUSHKA NOTEBOOK ',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'POSTAGE',
#   'RAINY LADIES BIRTHDAY CARD',
#   'ROBOT BIRTHDAY CARD',
#   'ROUND SNACK BOXES SET OF 4 SKULLS',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'SKULLS STORAGE BOX LARGE',
#   'SKULLS STORAGE BOX SMALL',
#   'SMALL PURPLE BABUSHKA NOTEBOOK ',
#   'SMALL RED BABUSHKA NOTEBOOK ',
#   'SMALL YELLOW BABUSHKA NOTEBOOK ',
#   'SNACK TRAY I LOVE LONDON',
#   'SPACEBOY BIRTHDAY CARD',
#   'SUKI  SHOULDER BAG',
#   'TEA PARTY BIRTHDAY CARD'],
#  ['ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE PINK',
#   'BAKING SET SPACEBOY DESIGN',
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'EMBROIDERED RIBBON REEL DAISY ',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'MINI JIGSAW CIRCUS PARADE ',
#   'MINI JIGSAW SPACEBOY',
#   'MINI LIGHTS WOODLAND MUSHROOMS',
#   'PACK OF 20 SPACEBOY NAPKINS',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RETROSPOT CHILDRENS APRON',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'SET OF 6 RIBBONS PERFECTLY PRETTY  ',
#   'SPOTTY BUNTING',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'WOODLAND MINI BACKPACK'],
#  ['4 TRADITIONAL SPINNING TOPS',
#   'BLUE HARMONICA IN BOX ',
#   'COWBOYS AND INDIANS BIRTHDAY CARD ',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'PARISIENNE JEWELLERY DRAWER ',
#   'PENNY FARTHING BIRTHDAY CARD',
#   'POSTAGE',
#   'RABBIT NIGHT LIGHT',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT UMBRELLA',
#   'SET OF 4 JAM JAR MAGNETS',
#   'SPACEBOY BIRTHDAY CARD',
#   'TEA PARTY BIRTHDAY CARD',
#   'TRADITIONAL PICK UP STICKS GAME ',
#   'TRADITIONAL WOODEN SKIPPING ROPE',
#   'VICTORIAN SEWING BOX LARGE',
#   'WOODEN BOX OF DOMINOES',
#   'WORLD WAR 2 GLIDERS ASSTD DESIGNS'],
#  ['CAKE STAND WHITE TWO TIER LACE', 'POSTAGE', 'REGENCY CAKESTAND 3 TIER'],
#  ['ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE IVORY',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'BAKING SET 9 PIECE RETROSPOT ',
#   "CHILDREN'S APRON DOLLY GIRL ",
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'CHILDRENS CUTLERY CIRCUS PARADE',
#   'CHILDRENS CUTLERY DOLLY GIRL ',
#   'CHILDRENS CUTLERY SPACEBOY ',
#   'CIRCUS PARADE LUNCH BOX ',
#   'PACK OF 20 SPACEBOY NAPKINS',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN STRONGMAN',
#   'SPACEBOY LUNCH BOX ']]

# %% [markdown]
# Patterns with minimum threshold support count=10

# %%
patterns=fp.find_frequent_patterns(t,10)
patterns
# Out:
# {('PICTURE DOMINOES',): 10,
#  ('RED RETROSPOT BUTTER DISH',): 10,
#  ('RETROSPOT HEART HOT WATER BOTTLE',): 10,
#  ('DOORMAT RED RETROSPOT',): 10,
#  ('SPACEBOY CHILDRENS EGG CUP',): 10,
#  ('TOADSTOOL MONEY BOX',): 10,
#  ('PACK OF 72 SKULL CAKE CASES',): 10,
#  ('RED RETROSPOT TAPE',): 10,
#  ('PACK OF 60 SPACEBOY CAKE CASES',): 10,
#  ('CHILDRENS CUTLERY RETROSPOT RED ',): 10,
#  ('CHILDRENS CUTLERY RETROSPOT RED ', 'POSTAGE'): 10,
#  ('SKULL AND CROSSBONES  GARLAND ',): 10,
#  ('PINK  POLKADOT CUP',): 10,
#  ('PINK  POLKADOT CUP', 'POSTAGE'): 10,
#  ('RECYCLED ACAPULCO MAT PINK',): 10,
#  ('RECYCLED ACAPULCO MAT LAVENDER',): 10,
#  ('SET OF 5 LUCKY CAT MAGNETS ',): 10,
#  ('LUNCH BAG VINTAGE LEAF DESIGN',): 10,
#  ('RECYCLING BAG RETROSPOT ',): 10,
#  ('POSTAGE', 'RECYCLING BAG RETROSPOT '): 10,
#  ('JUMBO BAG DOILEY PATTERNS',): 10,
#  ('SET OF 60 I LOVE LONDON CAKE CASES ',): 10,
#  ('SET 2 TEA TOWELS I LOVE LONDON ',): 10,
#  ('6 GIFT TAGS VINTAGE CHRISTMAS ',): 10,
#  ('BOX OF 6 MINI VINTAGE CRACKERS',): 10,
#  ('SET 12 COLOUR PENCILS SPACEBOY ',): 10,
#  ('MINI JIGSAW CIRCUS PARADE ',): 11,
#  ('MINI JIGSAW CIRCUS PARADE ', 'POSTAGE'): 10,
#  ('VINTAGE HEADS AND TAILS CARD GAME ',): 11,
#  ('POSTAGE', 'VINTAGE HEADS AND TAILS CARD GAME '): 10,
#  ('BIG DOUGHNUT FRIDGE MAGNETS',): 11,
#  ('LUNCH BAG CARS BLUE',): 11,
#  ('TEA BAG PLATE RED RETROSPOT',): 11,
#  ('SET 7 BABUSHKA NESTING BOXES',): 11,
#  ('ALARM CLOCK BAKELIKE CHOCOLATE',): 11,
#  ('ALARM CLOCK BAKELIKE CHOCOLATE', 'POSTAGE'): 11,
#  ('QUEENS GUARD COFFEE MUG',): 11,
#  ('WORLD WAR 2 GLIDERS ASSTD DESIGNS',): 11,
#  ('POSTAGE', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS'): 10,
#  ('RAINY LADIES BIRTHDAY CARD',): 11,
#  ('POSTAGE', 'RAINY LADIES BIRTHDAY CARD'): 10,
#  ('RED RETROSPOT SMALL MILK JUG',): 11,
#  ('ROSES REGENCY TEACUP AND SAUCER ',): 11,
#  ('GIRAFFE WOODEN RULER',): 11,
#  ('JUMBO BAG DOLLY GIRL DESIGN',): 11,
#  ('POPCORN HOLDER',): 11,
#  ("BOX OF 6 MINI 50'S CRACKERS",): 11,
#  ('WRAP  VINTAGE DOILY ',): 11,
#  ('SET OF 6 SOLDIER SKITTLES',): 12,
#  ('COFFEE MUG CAT + BIRD DESIGN',): 12,
#  ('COFFEE MUG CAT + BIRD DESIGN', 'POSTAGE'): 10,
#  ('10 COLOUR SPACEBOY PEN',): 12,
#  ('10 COLOUR SPACEBOY PEN', 'POSTAGE'): 12,
#  ("CHILDREN'S CIRCUS PARADE MUG",): 12,
#  ("CHILDREN'S CIRCUS PARADE MUG", 'POSTAGE'): 12,
#  ("CHILDREN'S SPACEBOY MUG",): 12,
#  ('WRAP RED APPLES ',): 12,
#  ('POSTAGE', 'WRAP RED APPLES '): 12,
#  ('DOORMAT UNION FLAG',): 12,
#  ('EDWARDIAN PARASOL NATURAL',): 12,
#  ('EDWARDIAN PARASOL NATURAL', 'POSTAGE'): 11,
#  ('PACK OF 60 PINK PAISLEY CAKE CASES',): 12,
#  ('PACK OF 60 PINK PAISLEY CAKE CASES', 'POSTAGE'): 10,
#  ('PIGGY BANK RETROSPOT ',): 12,
#  ('PIGGY BANK RETROSPOT ', 'POSTAGE'): 11,
#  ('ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE RED '): 10,
#  ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE IVORY'): 10,
#  ('CAKE STAND WHITE TWO TIER LACE',): 12,
#  ('CAKE STAND WHITE TWO TIER LACE', 'POSTAGE'): 11,
#  ('JAM MAKING SET WITH JARS',): 12,
#  ('RECYCLED ACAPULCO MAT RED',): 12,
#  ('RECYCLED ACAPULCO MAT TURQUOISE',): 12,
#  ('POSTAGE', 'RECYCLED ACAPULCO MAT TURQUOISE'): 11,
#  ('SET OF 5 PANCAKE DAY MAGNETS',): 12,
#  ('POSTAGE', 'SET OF 5 PANCAKE DAY MAGNETS'): 11,
#  ('CHILDRENS CUTLERY CIRCUS PARADE', 'CHILDRENS CUTLERY SPACEBOY '): 10,
#  ('CHILDRENS CUTLERY CIRCUS PARADE', 'CHILDRENS CUTLERY DOLLY GIRL '): 10,
#  ('CARD DOLLY GIRL ',): 12,
#  ('CARD DOLLY GIRL ', 'SPACEBOY BIRTHDAY CARD'): 11,
#  ('RED VINTAGE SPOT BEAKER',): 12,
#  ('POSTAGE', 'RED VINTAGE SPOT BEAKER'): 11,
#  ('SET OF 12 MINI LOAF BAKING CASES',): 12,
#  ('POSTAGE', 'SET OF 12 MINI LOAF BAKING CASES'): 10,
#  ('SET OF 6 TEA TIME BAKING CASES',): 12,
#  ('POSTAGE', 'SET OF 6 TEA TIME BAKING CASES'): 11,
#  ('STARS GIFT TAPE ',): 13,
#  ('POSTAGE', 'STARS GIFT TAPE '): 12,
#  ('EDWARDIAN PARASOL RED',): 13,
#  ('EDWARDIAN PARASOL RED', 'POSTAGE'): 12,
#  ('CHILDS BREAKFAST SET DOLLY GIRL ', 'POSTAGE'): 10,
#  ('CHILDS BREAKFAST SET DOLLY GIRL ', 'CHILDS BREAKFAST SET SPACEBOY '): 12,
#  ('SKULLS  WATER TRANSFER TATTOOS ',): 13,
#  ('POSTAGE', 'SKULLS  WATER TRANSFER TATTOOS '): 12,
#  ('FELTCRAFT PRINCESS LOLA DOLL',): 13,
#  ("POPPY'S PLAYHOUSE BATHROOM",): 13,
#  ("POPPY'S PLAYHOUSE BATHROOM", "POPPY'S PLAYHOUSE BEDROOM "): 10,
#  ("POPPY'S PLAYHOUSE BATHROOM", "POPPY'S PLAYHOUSE KITCHEN"): 12,
#  ("POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE BEDROOM ",
#   "POPPY'S PLAYHOUSE KITCHEN"): 10,
#  ('FAWN BLUE HOT WATER BOTTLE',): 13,
#  ('EASTER TIN BUNNY BOUQUET',): 13,
#  ('EASTER TIN BUNNY BOUQUET', 'POSTAGE'): 11,
#  ('BLUE POLKADOT CUP',): 13,
#  ('BLUE POLKADOT CUP', 'POSTAGE'): 13,
#  ('BLACK/BLUE POLKADOT UMBRELLA',): 13,
#  ('RED RETROSPOT SHOPPING BAG',): 13,
#  ('POSTAGE', 'RED RETROSPOT SHOPPING BAG'): 10,
#  ('SET OF 72 RETROSPOT PAPER  DOILIES',): 13,
#  ('RED RETROSPOT PLATE ',): 13,
#  ('POSTAGE', 'RED RETROSPOT PLATE '): 12,
#  ('PICNIC BOXES SET OF 3 RETROSPOT ',): 13,
#  ('PICNIC BOXES SET OF 3 RETROSPOT ',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('LUNCH BAG  BLACK SKULL.',): 13,
#  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'): 10,
#  ('LUNCH BAG DOILEY PATTERN ',): 13,
#  ('LUNCH BAG DOILEY PATTERN ', 'POSTAGE'): 11,
#  ('SET OF 3 REGENCY CAKE TINS',): 13,
#  ('DOLLY GIRL CHILDRENS BOWL', 'SPACEBOY CHILDRENS CUP'): 11,
#  ('DOLLY GIRL CHILDRENS BOWL', 'POSTAGE', 'SPACEBOY CHILDRENS CUP'): 10,
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): 11,
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS CUP'): 11,
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): 10,
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS CUP'): 10,
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): 11,
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): 10,
#  ('DOLLY GIRL CHILDRENS CUP', 'SPACEBOY CHILDRENS CUP'): 12,
#  ('SPACEBOY CHILDRENS BOWL', 'SPACEBOY CHILDRENS CUP'): 12,
#  ('DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): 11,
#  ('POSTAGE', 'SPACEBOY CHILDRENS BOWL', 'SPACEBOY CHILDRENS CUP'): 11,
#  ('DOLLY GIRL CHILDRENS CUP', 'POSTAGE', 'SPACEBOY CHILDRENS CUP'): 11,
#  ('DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): 10,
#  ('SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET/10 RED POLKADOT PARTY CANDLES'): 10,
#  ('POSTAGE', 'SET/10 BLUE POLKADOT PARTY CANDLES'): 11,
#  ('SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES'): 11,
#  ('BAKING SET 9 PIECE RETROSPOT ', 'BAKING SET SPACEBOY DESIGN'): 11,
#  ('BAKING SET SPACEBOY DESIGN', 'POSTAGE'): 11,
#  ("POPPY'S PLAYHOUSE LIVINGROOM ",): 14,
#  ("POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE LIVINGROOM "): 10,
#  ("POPPY'S PLAYHOUSE KITCHEN", "POPPY'S PLAYHOUSE LIVINGROOM "): 12,
#  ("POPPY'S PLAYHOUSE BEDROOM ",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   "POPPY'S PLAYHOUSE LIVINGROOM "): 10,
#  ('3 PIECE SPACEBOY COOKIE CUTTER SET',): 14,
#  ('3 PIECE SPACEBOY COOKIE CUTTER SET', 'POSTAGE'): 13,
#  ('JUMBO STORAGE BAG SUKI',): 14,
#  ('JUMBO STORAGE BAG SUKI', 'POSTAGE'): 13,
#  ('JUMBO BAG APPLES', 'JUMBO BAG PEARS'): 11,
#  ('JUMBO BAG PEARS', 'POSTAGE'): 12,
#  ('SET OF 12 FAIRY CAKE BAKING CASES',): 14,
#  ('POSTAGE', 'SET OF 12 FAIRY CAKE BAKING CASES'): 11,
#  ('MINI JIGSAW SPACEBOY',): 15,
#  ('MINI JIGSAW SPACEBOY', 'POSTAGE'): 13,
#  ('WOODLAND PARTY BAG + STICKER SET',): 15,
#  ('RETROSPOT PARTY BAG + STICKER SET', 'WOODLAND PARTY BAG + STICKER SET'): 14,
#  ('POSTAGE', 'WOODLAND PARTY BAG + STICKER SET'): 13,
#  ('POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'WOODLAND PARTY BAG + STICKER SET'): 13,
#  ('JUMBO BAG PINK POLKADOT',): 15,
#  ('JUMBO BAG PINK POLKADOT', 'POSTAGE'): 14,
#  ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG WOODLAND ANIMALS'): 10,
#  ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG WOODLAND ANIMALS', 'POSTAGE'): 10,
#  ('PACK OF 60 MUSHROOM CAKE CASES',): 15,
#  ('PACK OF 60 MUSHROOM CAKE CASES', 'POSTAGE'): 14,
#  ('PLASTERS IN TIN VINTAGE PAISLEY ',): 15,
#  ('PLASTERS IN TIN VINTAGE PAISLEY ', 'POSTAGE'): 14,
#  ('RED RETROSPOT UMBRELLA',): 15,
#  ('POSTAGE', 'RED RETROSPOT UMBRELLA'): 13,
#  ('RED RETROSPOT BOWL',): 15,
#  ('POSTAGE', 'RED RETROSPOT BOWL'): 12,
#  ('SET OF 10 LED DOLLY LIGHTS',): 15,
#  ('POSTAGE', 'SET OF 10 LED DOLLY LIGHTS'): 11,
#  ('BUNDLE OF 3 ALPHABET EXERCISE BOOKS', 'PLASTERS IN TIN CIRCUS PARADE '): 10,
#  ('BUNDLE OF 3 ALPHABET EXERCISE BOOKS', 'POSTAGE'): 11,
#  ('SPACEBOY MINI BACKPACK', 'WOODLAND MINI BACKPACK'): 12,
#  ('POSTAGE', 'SPACEBOY MINI BACKPACK', 'WOODLAND MINI BACKPACK'): 10,
#  ('DOLLY GIRL MINI BACKPACK', 'POSTAGE', 'SPACEBOY MINI BACKPACK'): 10,
#  ('DOLLY GIRL MINI BACKPACK',
#   'SPACEBOY MINI BACKPACK',
#   'WOODLAND MINI BACKPACK'): 11,
#  ('POSTAGE', 'SPACEBOY MINI BACKPACK'): 13,
#  ('ROBOT BIRTHDAY CARD',): 16,
#  ('POSTAGE', 'ROBOT BIRTHDAY CARD'): 14,
#  ('CLOTHES PEGS RETROSPOT PACK 24 ',): 16,
#  ('LONDON BUS COFFEE MUG',): 16,
#  ('MAGNETS PACK OF 4 SWALLOWS',): 16,
#  ('LUNCH BAG PINK POLKADOT',): 16,
#  (' SPACEBOY BABY GIFT SET',): 16,
#  ('JUMBO BAG VINTAGE LEAF',): 16,
#  ('JUMBO BAG VINTAGE LEAF', 'POSTAGE'): 15,
#  ('DOLLY GIRL CHILDRENS CUP', 'POSTAGE'): 13,
#  ('DOLLY GIRL CHILDRENS BOWL', 'DOLLY GIRL CHILDRENS CUP', 'POSTAGE'): 12,
#  ('DOLLY GIRL CHILDRENS CUP', 'POSTAGE', 'SPACEBOY CHILDRENS BOWL'): 10,
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL'): 10,
#  ('DOLLY GIRL CHILDRENS CUP', 'SPACEBOY CHILDRENS BOWL'): 13,
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS BOWL'): 13,
#  ('DOLLY GIRL CHILDRENS BOWL', 'DOLLY GIRL CHILDRENS CUP'): 15,
#  ('DOLLY GIRL MINI BACKPACK',): 16,
#  ('DOLLY GIRL MINI BACKPACK', 'POSTAGE'): 14,
#  ('DOLLY GIRL MINI BACKPACK', 'WOODLAND MINI BACKPACK'): 14,
#  ('POSTAGE', 'WOODLAND MINI BACKPACK'): 14,
#  ('DOLLY GIRL MINI BACKPACK', 'POSTAGE', 'WOODLAND MINI BACKPACK'): 12,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'SET OF SALT AND PEPPER TOADSTOOLS'): 10,
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'SET OF SALT AND PEPPER TOADSTOOLS'): 10,
#  ('POSTAGE', 'SET OF SALT AND PEPPER TOADSTOOLS'): 12,
#  ('ALARM CLOCK BAKELIKE ORANGE', 'PLASTERS IN TIN CIRCUS PARADE '): 10,
#  ('ALARM CLOCK BAKELIKE ORANGE', 'PLASTERS IN TIN WOODLAND ANIMALS'): 11,
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE PINK', 'POSTAGE'): 10,
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'POSTAGE'): 10,
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK'): 11,
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED '): 11,
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED '): 12,
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN SPACEBOY'): 10,
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN SPACEBOY'): 10,
#  ('ALARM CLOCK BAKELIKE ORANGE', 'PLASTERS IN TIN SPACEBOY', 'POSTAGE'): 10,
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'PLASTERS IN TIN SPACEBOY'): 11,
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN SPACEBOY'): 11,
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN SPACEBOY'): 10,
#  ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE ORANGE', 'POSTAGE'): 11,
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE RED ',
#   'POSTAGE'): 10,
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE RED '): 12,
#  ('ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE RED '): 14,
#  ('ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE RED ', 'POSTAGE'): 12,
#  ('ALARM CLOCK BAKELIKE ORANGE', 'POSTAGE'): 15,
#  ('CHILDS BREAKFAST SET CIRCUS PARADE',): 17,
#  ('CHILDS BREAKFAST SET CIRCUS PARADE', 'POSTAGE'): 14,
#  ('CHILDS BREAKFAST SET SPACEBOY ', 'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('CHILDS BREAKFAST SET SPACEBOY ', 'POSTAGE'): 14,
#  ("POPPY'S PLAYHOUSE BEDROOM ", 'POSTAGE'): 10,
#  ('LUNCH BAG RED RETROSPOT', "POPPY'S PLAYHOUSE BEDROOM "): 11,
#  ("POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE KITCHEN"): 15,
#  ('CHILDRENS APRON APPLES DESIGN',): 17,
#  ('CHILDRENS APRON APPLES DESIGN', 'POSTAGE'): 16,
#  ('ASSORTED COLOUR BIRD ORNAMENT',): 17,
#  ('GINGERBREAD MAN COOKIE CUTTER',): 17,
#  ('GINGERBREAD MAN COOKIE CUTTER', 'PLASTERS IN TIN CIRCUS PARADE '): 10,
#  ('GINGERBREAD MAN COOKIE CUTTER', 'POSTAGE'): 17,
#  ('GINGERBREAD MAN COOKIE CUTTER',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE'): 10,
#  ('CHARLOTTE BAG SUKI DESIGN',): 17,
#  ('CHARLOTTE BAG SUKI DESIGN', 'POSTAGE'): 16,
#  ('POSTAGE', 'WATERING CAN BLUE ELEPHANT'): 10,
#  ('WATERING CAN BLUE ELEPHANT', 'WATERING CAN PINK BUNNY'): 11,
#  ('CHILDRENS CUTLERY POLKADOT PINK', 'CHILDRENS CUTLERY SPACEBOY '): 10,
#  ('CHILDRENS CUTLERY DOLLY GIRL ', 'CHILDRENS CUTLERY POLKADOT PINK'): 10,
#  ('CHILDRENS CUTLERY POLKADOT PINK', 'POSTAGE'): 16,
#  ('SPOTTY BUNTING',): 17,
#  ('POSTAGE', 'SPOTTY BUNTING'): 17,
#  ('SET OF 4 KNICK KNACK TINS LONDON ',): 17,
#  ('POSTAGE', 'SET OF 4 KNICK KNACK TINS LONDON '): 13,
#  ('ICE CREAM BUBBLES',): 17,
#  ('ICE CREAM BUBBLES', 'POSTAGE'): 17,
#  ('EDWARDIAN PARASOL BLACK',): 18,
#  ('EDWARDIAN PARASOL BLACK', 'POSTAGE'): 16,
#  ('COFFEE MUG APPLES DESIGN', 'COFFEE MUG PEARS  DESIGN'): 13,
#  ('COFFEE MUG APPLES DESIGN', 'COFFEE MUG PEARS  DESIGN', 'POSTAGE'): 11,
#  ('COFFEE MUG PEARS  DESIGN', 'POSTAGE'): 15,
#  ('SET OF 20 KIDS COOKIE CUTTERS',): 18,
#  ('POSTAGE', 'SET OF 20 KIDS COOKIE CUTTERS'): 15,
#  ('36 PENCILS TUBE RED RETROSPOT',): 18,
#  ('36 PENCILS TUBE RED RETROSPOT', 'POSTAGE'): 10,
#  ('ICE CREAM SUNDAE LIP GLOSS',): 18,
#  ('ICE CREAM SUNDAE LIP GLOSS', 'POSTAGE'): 13,
#  ('DOLLY GIRL CHILDRENS BOWL', 'POSTAGE'): 15,
#  ('DOLLY GIRL CHILDRENS BOWL', 'POSTAGE', 'SPACEBOY CHILDRENS BOWL'): 13,
#  ('DOLLY GIRL CHILDRENS BOWL', 'SPACEBOY CHILDRENS BOWL'): 16,
#  ('RED RETROSPOT CUP',): 19,
#  ('POSTAGE', 'RED RETROSPOT CUP'): 19,
#  ('TABLECLOTH RED APPLES DESIGN ',): 19,
#  ('SET OF 2 TEA TOWELS APPLE AND PEARS', 'TABLECLOTH RED APPLES DESIGN '): 11,
#  ('POSTAGE', 'TABLECLOTH RED APPLES DESIGN '): 19,
#  ('POSTAGE',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'TABLECLOTH RED APPLES DESIGN '): 11,
#  ('RED RETROSPOT CAKE STAND',): 19,
#  ('POSTAGE', 'RED RETROSPOT CAKE STAND'): 14,
#  ('SET/10 PINK POLKADOT PARTY CANDLES',
#   'SET/10 RED POLKADOT PARTY CANDLES'): 13,
#  ('POSTAGE', 'SET/10 PINK POLKADOT PARTY CANDLES'): 15,
#  ('PACK OF 20 SKULL PAPER NAPKINS', 'SET OF 9 BLACK SKULL BALLOONS'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET OF 9 BLACK SKULL BALLOONS'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS', 'SET OF 9 HEART SHAPED BALLOONS'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET OF 9 HEART SHAPED BALLOONS'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 13,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 13,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS'): 12,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): 11,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): 14,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): 13,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS'): 14,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES'): 15,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE'): 15,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE'): 14,
#  ('PACK OF 20 SKULL PAPER NAPKINS', 'PACK OF 6 SKULL PAPER PLATES'): 17,
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE'): 16,
#  ('PACK OF 20 SKULL PAPER NAPKINS', 'POSTAGE'): 18,
#  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN '): 11,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG SUKI DESIGN '): 11,
#  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG SUKI DESIGN ', 'POSTAGE'): 11,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG SUKI DESIGN ',
#   'POSTAGE'): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG SUKI DESIGN '): 14,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG SUKI DESIGN ', 'POSTAGE'): 12,
#  ('LUNCH BAG SUKI DESIGN ', 'POSTAGE'): 16,
#  ('JUMBO BAG VINTAGE DOILY ',): 19,
#  ('JUMBO BAG VINTAGE DOILY ', 'POSTAGE'): 18,
#  ('JUMBO BAG APPLES', 'JUMBO BAG VINTAGE DOILY '): 10,
#  ('JUMBO BAG APPLES', 'JUMBO BAG VINTAGE DOILY ', 'POSTAGE'): 10,
#  ('PACK OF 20 NAPKINS RED APPLES',): 20,
#  ('PACK OF 20 NAPKINS RED APPLES', 'POSTAGE'): 19,
#  ("CHILDREN'S APRON DOLLY GIRL ", 'CHILDRENS APRON SPACEBOY DESIGN'): 13,
#  ("CHILDREN'S APRON DOLLY GIRL ", 'POSTAGE'): 15,
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'SKULL LUNCH BOX WITH CUTLERY '): 10,
#  ('SKULL LUNCH BOX WITH CUTLERY ', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('POSTAGE',
#   'SKULL LUNCH BOX WITH CUTLERY ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ', 'SKULL LUNCH BOX WITH CUTLERY '): 13,
#  ('POSTAGE', 'SKULL LUNCH BOX WITH CUTLERY '): 14,
#  ('BLUE HARMONICA IN BOX ', 'RED  HARMONICA IN BOX '): 10,
#  ('BLUE HARMONICA IN BOX ', 'LUNCH BAG RED RETROSPOT'): 10,
#  ('BLUE HARMONICA IN BOX ',
#   'LUNCH BAG RED RETROSPOT',
#   'RED  HARMONICA IN BOX '): 10,
#  ('BLUE HARMONICA IN BOX ', 'POSTAGE'): 13,
#  ('ROUND SNACK BOXES SET OF4 WOODLAND ', 'SPACEBOY CHILDRENS BOWL'): 10,
#  ('PLASTERS IN TIN SPACEBOY', 'SPACEBOY CHILDRENS BOWL'): 10,
#  ('POSTAGE', 'SPACEBOY CHILDRENS BOWL'): 17,
#  ('LUNCH BAG VINTAGE DOILY ', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG VINTAGE DOILY '): 10,
#  ('LUNCH BAG VINTAGE DOILY ', 'POSTAGE'): 17,
#  ('MINI LIGHTS WOODLAND MUSHROOMS', 'RABBIT NIGHT LIGHT'): 17,
#  ('MINI LIGHTS WOODLAND MUSHROOMS', 'POSTAGE'): 17,
#  ('MINI LIGHTS WOODLAND MUSHROOMS', 'POSTAGE', 'RABBIT NIGHT LIGHT'): 15,
#  ('JAM MAKING SET PRINTED', 'PLASTERS IN TIN WOODLAND ANIMALS'): 11,
#  ('JAM MAKING SET PRINTED', 'PLASTERS IN TIN WOODLAND ANIMALS', 'POSTAGE'): 10,
#  ('JAM MAKING SET PRINTED', 'POSTAGE'): 20,
#  ('SMALL RED RETROSPOT WINDMILL',): 21,
#  ('POSTAGE', 'SMALL RED RETROSPOT WINDMILL'): 18,
#  ('PARTY BUNTING',): 22,
#  ('PARTY BUNTING', 'POSTAGE'): 20,
#  ('CIRCUS PARADE CHILDRENS EGG CUP ', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('CIRCUS PARADE CHILDRENS EGG CUP ', 'LUNCH BOX WITH CUTLERY RETROSPOT '): 11,
#  ('CIRCUS PARADE CHILDRENS EGG CUP ',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE'): 10,
#  ('CIRCUS PARADE CHILDRENS EGG CUP ', 'RED RETROSPOT MINI CASES'): 11,
#  ('CIRCUS PARADE CHILDRENS EGG CUP ',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES'): 10,
#  ('CIRCUS PARADE CHILDRENS EGG CUP ', 'PLASTERS IN TIN CIRCUS PARADE '): 13,
#  ('CIRCUS PARADE CHILDRENS EGG CUP ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE'): 13,
#  ('CIRCUS PARADE CHILDRENS EGG CUP ', 'POSTAGE'): 20,
#  ('PLASTERS IN TIN SKULLS', 'PLASTERS IN TIN STRONGMAN'): 10,
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'PLASTERS IN TIN SKULLS'): 12,
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'PLASTERS IN TIN SKULLS', 'POSTAGE'): 11,
#  ('PLASTERS IN TIN SKULLS', 'PLASTERS IN TIN WOODLAND ANIMALS'): 12,
#  ('PLASTERS IN TIN SKULLS', 'POSTAGE'): 16,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS'): 10,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET OF 9 BLACK SKULL BALLOONS'): 11,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS'): 11,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS'): 10,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 13,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 13,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 12,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 12,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 12,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 11,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): 15,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS'): 14,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): 13,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): 15,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 15,
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 16,
#  ('PACK OF 6 SKULL PAPER CUPS', 'PACK OF 6 SKULL PAPER PLATES'): 20,
#  ('PACK OF 6 SKULL PAPER CUPS', 'PACK OF 6 SKULL PAPER PLATES', 'POSTAGE'): 19,
#  ('PACK OF 6 SKULL PAPER PLATES', 'POSTAGE'): 21,
#  ('CHILDRENS APRON SPACEBOY DESIGN', 'RETROSPOT CHILDRENS APRON'): 11,
#  ('CHILDRENS APRON SPACEBOY DESIGN',
#   'POSTAGE',
#   'RETROSPOT CHILDRENS APRON'): 10,
#  ('POSTAGE', 'RETROSPOT CHILDRENS APRON'): 18,
#  ('REVOLVER WOODEN RULER ',): 22,
#  ('POSTAGE', 'REVOLVER WOODEN RULER '): 17,
#  ('GUMBALL COAT RACK', 'LUNCH BOX WITH CUTLERY RETROSPOT '): 11,
#  ('GUMBALL COAT RACK', 'LUNCH BOX WITH CUTLERY RETROSPOT ', 'POSTAGE'): 11,
#  ('GUMBALL COAT RACK', 'RED RETROSPOT MINI CASES'): 13,
#  ('GUMBALL COAT RACK', 'POSTAGE', 'RED RETROSPOT MINI CASES'): 12,
#  ('GUMBALL COAT RACK', 'POSTAGE'): 22,
#  ('CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT MINI CASES'): 10,
#  ('CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG'): 13,
#  ('CHARLOTTE BAG PINK POLKADOT', 'POSTAGE', 'RED RETROSPOT CHARLOTTE BAG'): 10,
#  ('CHARLOTTE BAG PINK POLKADOT', 'POSTAGE'): 18,
#  ('WATERING CAN PINK BUNNY',): 23,
#  ('POSTAGE', 'WATERING CAN PINK BUNNY'): 17,
#  ('LUNCH BAG RED RETROSPOT', "POPPY'S PLAYHOUSE KITCHEN"): 11,
#  ("POPPY'S PLAYHOUSE KITCHEN", 'POSTAGE'): 17,
#  ('RETROSPOT PARTY BAG + STICKER SET', 'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('RETROSPOT PARTY BAG + STICKER SET',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 11,
#  ('POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 11,
#  ('RETROSPOT PARTY BAG + STICKER SET', 'SET/6 RED SPOTTY PAPER CUPS'): 13,
#  ('POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER CUPS'): 12,
#  ('POSTAGE', 'RETROSPOT PARTY BAG + STICKER SET'): 23,
#  ('JUMBO BAG SPACEBOY DESIGN', 'LUNCH BAG WOODLAND'): 10,
#  ('JUMBO BAG SPACEBOY DESIGN', 'LUNCH BAG RED RETROSPOT'): 10,
#  ('JUMBO BAG SPACEBOY DESIGN', 'JUMBO BAG WOODLAND ANIMALS'): 10,
#  ('JUMBO BAG SPACEBOY DESIGN', 'JUMBO BAG WOODLAND ANIMALS', 'POSTAGE'): 10,
#  ('JUMBO BAG APPLES', 'JUMBO BAG SPACEBOY DESIGN'): 10,
#  ('JUMBO BAG SPACEBOY DESIGN', 'LUNCH BAG SPACEBOY DESIGN '): 11,
#  ('JUMBO BAG SPACEBOY DESIGN', 'PLASTERS IN TIN SPACEBOY'): 11,
#  ('JUMBO BAG SPACEBOY DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('JUMBO BAG SPACEBOY DESIGN', 'LUNCH BAG APPLE DESIGN'): 11,
#  ('JUMBO BAG SPACEBOY DESIGN', 'PLASTERS IN TIN CIRCUS PARADE '): 12,
#  ('JUMBO BAG SPACEBOY DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 11,
#  ('JUMBO BAG SPACEBOY DESIGN', 'PLASTERS IN TIN WOODLAND ANIMALS'): 13,
#  ('JUMBO BAG SPACEBOY DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): 10,
#  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG SPACEBOY DESIGN'): 14,
#  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG SPACEBOY DESIGN', 'POSTAGE'): 13,
#  ('JUMBO BAG SPACEBOY DESIGN', 'POSTAGE'): 22,
#  ('PACK OF 6 SKULL PAPER CUPS', 'SET OF 9 BLACK SKULL BALLOONS'): 11,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS'): 10,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 12,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 15,
#  ('PACK OF 6 SKULL PAPER CUPS', 'SET/20 RED RETROSPOT PAPER NAPKINS '): 17,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 16,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 14,
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 13,
#  ('PACK OF 6 SKULL PAPER CUPS', 'POSTAGE', 'SET/6 RED SPOTTY PAPER CUPS'): 16,
#  ('PACK OF 6 SKULL PAPER CUPS', 'POSTAGE'): 24,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'LUNCH BAG SPACEBOY DESIGN '): 10,
#  ('CHARLOTTE BAG APPLES DESIGN', 'CHARLOTTE BAG DOLLY GIRL DESIGN'): 10,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'PLASTERS IN TIN CIRCUS PARADE '): 11,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY'): 11,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'WOODLAND CHARLOTTE BAG'): 11,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'POSTAGE', 'WOODLAND CHARLOTTE BAG'): 10,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'RED RETROSPOT CHARLOTTE BAG'): 11,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'PLASTERS IN TIN WOODLAND ANIMALS'): 14,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 14,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): 12,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): 12,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'PLASTERS IN TIN SPACEBOY'): 15,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): 13,
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'POSTAGE'): 23,
#  ('SET OF 9 BLACK SKULL BALLOONS', 'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('SET OF 9 BLACK SKULL BALLOONS', 'SET/6 RED SPOTTY PAPER CUPS'): 14,
#  ('SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS'): 13,
#  ('POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 13,
#  ('POSTAGE', 'SET OF 9 BLACK SKULL BALLOONS'): 25,
#  ('SET OF 9 HEART SHAPED BALLOONS',): 26,
#  ('SET OF 9 BLACK SKULL BALLOONS', 'SET OF 9 HEART SHAPED BALLOONS'): 11,
#  ('POSTAGE', 'SET OF 9 HEART SHAPED BALLOONS'): 22,
#  ('POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET OF 9 HEART SHAPED BALLOONS'): 11,
#  ('CHILDRENS APRON SPACEBOY DESIGN', 'SPACEBOY LUNCH BOX '): 10,
#  ('CHILDRENS APRON SPACEBOY DESIGN', 'POSTAGE'): 21,
#  ('JUMBO BAG APPLES', 'LUNCH BOX WITH CUTLERY RETROSPOT '): 10,
#  ('JUMBO BAG APPLES', 'RABBIT NIGHT LIGHT'): 11,
#  ('JUMBO BAG APPLES', 'POSTAGE', 'RABBIT NIGHT LIGHT'): 11,
#  ('JUMBO BAG APPLES', 'JUMBO BAG WOODLAND ANIMALS'): 12,
#  ('JUMBO BAG APPLES', 'JUMBO BAG WOODLAND ANIMALS', 'POSTAGE'): 12,
#  ('JUMBO BAG APPLES', 'JUMBO BAG RED RETROSPOT'): 13,
#  ('JUMBO BAG APPLES', 'JUMBO BAG RED RETROSPOT', 'POSTAGE'): 12,
#  ('JUMBO BAG APPLES', 'LUNCH BAG APPLE DESIGN'): 17,
#  ('JUMBO BAG APPLES', 'LUNCH BAG APPLE DESIGN', 'POSTAGE'): 15,
#  ('JUMBO BAG APPLES', 'POSTAGE'): 23,
#  ('CIRCUS PARADE LUNCH BOX ', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 11,
#  ('CIRCUS PARADE LUNCH BOX ', 'PLASTERS IN TIN SPACEBOY'): 11,
#  ('CIRCUS PARADE LUNCH BOX ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY'): 10,
#  ('CIRCUS PARADE LUNCH BOX ', 'PLASTERS IN TIN CIRCUS PARADE '): 13,
#  ('CIRCUS PARADE LUNCH BOX ', 'SPACEBOY LUNCH BOX '): 17,
#  ('CIRCUS PARADE LUNCH BOX ', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 15,
#  ('CIRCUS PARADE LUNCH BOX ', 'POSTAGE'): 21,
#  ('DOLLY GIRL LUNCH BOX', 'LUNCH BOX I LOVE LONDON'): 10,
#  ('LUNCH BOX I LOVE LONDON', 'RED RETROSPOT MINI CASES'): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BOX I LOVE LONDON'): 11,
#  ('CIRCUS PARADE LUNCH BOX ', 'LUNCH BOX I LOVE LONDON'): 12,
#  ('CIRCUS PARADE LUNCH BOX ', 'LUNCH BOX I LOVE LONDON', 'POSTAGE'): 10,
#  ('LUNCH BOX I LOVE LONDON', 'PLASTERS IN TIN SPACEBOY'): 12,
#  ('LUNCH BOX I LOVE LONDON', 'PLASTERS IN TIN CIRCUS PARADE '): 12,
#  ('LUNCH BOX I LOVE LONDON',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY'): 11,
#  ('LUNCH BOX I LOVE LONDON', 'SPACEBOY LUNCH BOX '): 13,
#  ('LUNCH BOX I LOVE LONDON', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 12,
#  ('LUNCH BOX I LOVE LONDON', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 13,
#  ('LUNCH BOX I LOVE LONDON',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 10,
#  ('LUNCH BOX I LOVE LONDON', 'POSTAGE'): 21,
#  ('ASSORTED COLOUR MINI CASES', 'RED RETROSPOT MINI CASES'): 18,
#  ('ASSORTED COLOUR MINI CASES', 'POSTAGE', 'RED RETROSPOT MINI CASES'): 16,
#  ('ASSORTED COLOUR MINI CASES', 'POSTAGE'): 25,
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'RED  HARMONICA IN BOX '): 11,
#  ('RED  HARMONICA IN BOX ', 'SPACEBOY LUNCH BOX '): 11,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ', 'RED  HARMONICA IN BOX '): 12,
#  ('LUNCH BAG RED RETROSPOT', 'RED  HARMONICA IN BOX '): 15,
#  ('LUNCH BAG RED RETROSPOT', 'POSTAGE', 'RED  HARMONICA IN BOX '): 10,
#  ('POSTAGE', 'RED  HARMONICA IN BOX '): 20,
#  ('RED RETROSPOT CHILDRENS UMBRELLA', 'RED TOADSTOOL LED NIGHT LIGHT'): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'RED RETROSPOT CHILDRENS UMBRELLA'): 10,
#  ('PLASTERS IN TIN SPACEBOY', 'RED RETROSPOT CHILDRENS UMBRELLA'): 10,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ', 'RED RETROSPOT CHILDRENS UMBRELLA'): 11,
#  ('LUNCH BAG RED RETROSPOT', 'RED RETROSPOT CHILDRENS UMBRELLA'): 11,
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'RED RETROSPOT CHILDRENS UMBRELLA'): 13,
#  ('POSTAGE', 'RED RETROSPOT CHILDRENS UMBRELLA'): 18,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): 10,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): 10,
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): 10,
#  ('RED TOADSTOOL LED NIGHT LIGHT', 'SET OF 2 TEA TOWELS APPLE AND PEARS'): 10,
#  ('POSTAGE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): 10,
#  ('ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): 10,
#  ('COFFEE MUG APPLES DESIGN', 'SET OF 2 TEA TOWELS APPLE AND PEARS'): 12,
#  ('COFFEE MUG APPLES DESIGN',
#   'POSTAGE',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): 12,
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'SET OF 2 TEA TOWELS APPLE AND PEARS'): 13,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): 12,
#  ('POSTAGE', 'SET OF 2 TEA TOWELS APPLE AND PEARS'): 25,
#  ('COFFEE MUG APPLES DESIGN', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('COFFEE MUG APPLES DESIGN', 'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('COFFEE MUG APPLES DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('COFFEE MUG APPLES DESIGN', 'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('COFFEE MUG APPLES DESIGN',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('COFFEE MUG APPLES DESIGN',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PLASTERS IN TIN CIRCUS PARADE '): 10,
#  ('COFFEE MUG APPLES DESIGN',
#   'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE'): 10,
#  ('COFFEE MUG APPLES DESIGN', 'PLASTERS IN TIN CIRCUS PARADE '): 13,
#  ('COFFEE MUG APPLES DESIGN', 'PLASTERS IN TIN CIRCUS PARADE ', 'POSTAGE'): 11,
#  ('COFFEE MUG APPLES DESIGN', 'POSTAGE'): 24,
#  ('CHARLOTTE BAG APPLES DESIGN', 'LUNCH BAG APPLE DESIGN'): 10,
#  ('CHARLOTTE BAG APPLES DESIGN', 'PLASTERS IN TIN WOODLAND ANIMALS'): 13,
#  ('CHARLOTTE BAG APPLES DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 12,
#  ('CHARLOTTE BAG APPLES DESIGN', 'PLASTERS IN TIN CIRCUS PARADE '): 14,
#  ('CHARLOTTE BAG APPLES DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE'): 10,
#  ('CHARLOTTE BAG APPLES DESIGN', 'RED RETROSPOT CHARLOTTE BAG'): 15,
#  ('CHARLOTTE BAG APPLES DESIGN', 'POSTAGE', 'RED RETROSPOT CHARLOTTE BAG'): 10,
#  ('CHARLOTTE BAG APPLES DESIGN', 'POSTAGE'): 21,
#  ('CHILDRENS CUTLERY SPACEBOY ', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 11,
#  ('CHILDRENS CUTLERY DOLLY GIRL ',
#   'CHILDRENS CUTLERY SPACEBOY ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 10,
#  ('CHILDRENS CUTLERY SPACEBOY ', 'POSTAGE'): 19,
#  ('CHILDRENS CUTLERY DOLLY GIRL ',
#   'CHILDRENS CUTLERY SPACEBOY ',
#   'POSTAGE'): 17,
#  ('CHILDRENS CUTLERY DOLLY GIRL ', 'CHILDRENS CUTLERY SPACEBOY '): 25,
#  ('4 TRADITIONAL SPINNING TOPS', 'MINI PAINT SET VINTAGE '): 11,
#  ('4 TRADITIONAL SPINNING TOPS', 'POSTAGE'): 22,
#  ('SET/6 RED SPOTTY PAPER CUPS', 'SPACEBOY BIRTHDAY CARD'): 10,
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'SPACEBOY BIRTHDAY CARD'): 10,
#  ('PLASTERS IN TIN SPACEBOY', 'SPACEBOY BIRTHDAY CARD'): 10,
#  ('SPACEBOY BIRTHDAY CARD', 'TEA PARTY BIRTHDAY CARD'): 12,
#  ('POSTAGE', 'SPACEBOY BIRTHDAY CARD', 'TEA PARTY BIRTHDAY CARD'): 11,
#  ('POSTAGE', 'SPACEBOY BIRTHDAY CARD'): 22,
#  ('JUMBO BAG RED RETROSPOT', 'RED RETROSPOT PICNIC BAG'): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'RED RETROSPOT PICNIC BAG'): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'POSTAGE', 'RED RETROSPOT PICNIC BAG'): 10,
#  ('LUNCH BAG RED RETROSPOT', 'RED RETROSPOT PICNIC BAG'): 14,
#  ('LUNCH BAG RED RETROSPOT', 'POSTAGE', 'RED RETROSPOT PICNIC BAG'): 14,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'RED RETROSPOT PICNIC BAG'): 10,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'POSTAGE',
#   'RED RETROSPOT PICNIC BAG'): 10,
#  ('LUNCH BAG APPLE DESIGN', 'RED RETROSPOT PICNIC BAG'): 14,
#  ('LUNCH BAG APPLE DESIGN', 'POSTAGE', 'RED RETROSPOT PICNIC BAG'): 14,
#  ('POSTAGE', 'RED RETROSPOT PICNIC BAG'): 27,
#  ('CHILDRENS CUTLERY DOLLY GIRL ', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 11,
#  ('CHILDRENS CUTLERY DOLLY GIRL ', 'POSTAGE'): 19,
#  ('RED TOADSTOOL LED NIGHT LIGHT', 'WOODLAND CHARLOTTE BAG'): 10,
#  ('POSTAGE', 'RED TOADSTOOL LED NIGHT LIGHT', 'WOODLAND CHARLOTTE BAG'): 10,
#  ('RETROSPOT TEA SET CERAMIC 11 PC ', 'WOODLAND CHARLOTTE BAG'): 10,
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'WOODLAND CHARLOTTE BAG'): 11,
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'POSTAGE', 'WOODLAND CHARLOTTE BAG'): 10,
#  ('PLASTERS IN TIN SPACEBOY', 'WOODLAND CHARLOTTE BAG'): 11,
#  ('PLASTERS IN TIN SPACEBOY', 'POSTAGE', 'WOODLAND CHARLOTTE BAG'): 10,
#  ('RED RETROSPOT CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG'): 17,
#  ('POSTAGE', 'RED RETROSPOT CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG'): 14,
#  ('POSTAGE', 'WOODLAND CHARLOTTE BAG'): 26,
#  ('SET/10 RED POLKADOT PARTY CANDLES', 'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('SET/10 RED POLKADOT PARTY CANDLES', 'SET/6 RED SPOTTY PAPER CUPS'): 10,
#  ('SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 10,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'SET/10 RED POLKADOT PARTY CANDLES'): 11,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE',
#   'SET/10 RED POLKADOT PARTY CANDLES'): 10,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('SET/10 RED POLKADOT PARTY CANDLES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 14,
#  ('POSTAGE',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 14,
#  ('POSTAGE', 'SET/10 RED POLKADOT PARTY CANDLES'): 25,
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG WOODLAND'): 11,
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG WOODLAND', 'POSTAGE'): 11,
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG RED RETROSPOT'): 12,
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG RED RETROSPOT', 'POSTAGE'): 12,
#  ('JUMBO BAG WOODLAND ANIMALS', 'PLASTERS IN TIN WOODLAND ANIMALS'): 12,
#  ('JUMBO BAG WOODLAND ANIMALS',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): 12,
#  ('JUMBO BAG WOODLAND ANIMALS', 'RABBIT NIGHT LIGHT'): 12,
#  ('JUMBO BAG WOODLAND ANIMALS', 'POSTAGE', 'RABBIT NIGHT LIGHT'): 12,
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG APPLE DESIGN'): 13,
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG APPLE DESIGN', 'POSTAGE'): 13,
#  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG WOODLAND ANIMALS'): 16,
#  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG WOODLAND ANIMALS', 'POSTAGE'): 16,
#  ('JUMBO BAG WOODLAND ANIMALS', 'POSTAGE'): 30,
#  ('ALARM CLOCK BAKELIKE PINK', 'PLASTERS IN TIN STRONGMAN'): 10,
#  ('PLASTERS IN TIN STRONGMAN', 'SPACEBOY LUNCH BOX '): 10,
#  ('ALARM CLOCK BAKELIKE RED ', 'PLASTERS IN TIN STRONGMAN'): 11,
#  ('ALARM CLOCK BAKELIKE RED ', 'PLASTERS IN TIN STRONGMAN', 'POSTAGE'): 10,
#  ('ALARM CLOCK BAKELIKE GREEN', 'PLASTERS IN TIN STRONGMAN'): 11,
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN STRONGMAN'): 10,
#  ('PLASTERS IN TIN STRONGMAN', 'RED RETROSPOT MINI CASES'): 12,
#  ('PLASTERS IN TIN STRONGMAN', 'POSTAGE', 'RED RETROSPOT MINI CASES'): 10,
#  ('PLASTERS IN TIN STRONGMAN', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 12,
#  ('PLASTERS IN TIN STRONGMAN',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 10,
#  ('PLASTERS IN TIN SPACEBOY', 'PLASTERS IN TIN STRONGMAN', 'POSTAGE'): 10,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'POSTAGE'): 10,
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
# ...
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 13,
#  ('ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('ALARM CLOCK BAKELIKE PINK', 'MINI PAINT SET VINTAGE '): 14,
#  ('ALARM CLOCK BAKELIKE PINK', 'MINI PAINT SET VINTAGE ', 'POSTAGE'): 11,
#  ('ALARM CLOCK BAKELIKE PINK', 'PLASTERS IN TIN SPACEBOY', 'POSTAGE'): 11,
#  ('ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY'): 12,
#  ('ALARM CLOCK BAKELIKE PINK', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 19,
#  ('ALARM CLOCK BAKELIKE PINK',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 17,
#  ('ALARM CLOCK BAKELIKE PINK', 'PLASTERS IN TIN CIRCUS PARADE '): 19,
#  ('ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE'): 14,
#  ('ALARM CLOCK BAKELIKE PINK', 'POSTAGE'): 35,
#  ('PACK OF 72 RETROSPOT CAKE CASES', 'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 72 RETROSPOT CAKE CASES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('PACK OF 72 RETROSPOT CAKE CASES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 11,
#  ('PACK OF 72 RETROSPOT CAKE CASES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('PACK OF 72 RETROSPOT CAKE CASES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 12,
#  ('PACK OF 72 RETROSPOT CAKE CASES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 10,
#  ('PACK OF 72 RETROSPOT CAKE CASES', 'SET/6 RED SPOTTY PAPER CUPS'): 13,
#  ('PACK OF 72 RETROSPOT CAKE CASES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): 10,
#  ('PACK OF 72 RETROSPOT CAKE CASES', 'POSTAGE'): 33,
#  ('MINI PAINT SET VINTAGE ', 'SPACEBOY LUNCH BOX '): 10,
#  ('MINI PAINT SET VINTAGE ', 'PLASTERS IN TIN SPACEBOY'): 10,
#  ('MINI PAINT SET VINTAGE ', 'PLASTERS IN TIN WOODLAND ANIMALS'): 13,
#  ('MINI PAINT SET VINTAGE ', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 14,
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 12,
#  ('MINI PAINT SET VINTAGE ', 'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('MINI PAINT SET VINTAGE ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('MINI PAINT SET VINTAGE ', 'POSTAGE', 'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('MINI PAINT SET VINTAGE ', 'SET/20 RED RETROSPOT PAPER NAPKINS '): 14,
#  ('MINI PAINT SET VINTAGE ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('MINI PAINT SET VINTAGE ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 14,
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): 10,
#  ('MINI PAINT SET VINTAGE ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 14,
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): 10,
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): 10,
#  ('MINI PAINT SET VINTAGE ', 'PLASTERS IN TIN CIRCUS PARADE '): 15,
#  ('MINI PAINT SET VINTAGE ', 'PLASTERS IN TIN CIRCUS PARADE ', 'POSTAGE'): 12,
#  ('MINI PAINT SET VINTAGE ', 'SET/6 RED SPOTTY PAPER CUPS'): 15,
#  ('MINI PAINT SET VINTAGE ', 'POSTAGE', 'SET/6 RED SPOTTY PAPER CUPS'): 11,
#  ('MINI PAINT SET VINTAGE ', 'POSTAGE'): 32,
#  ('ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('POSTAGE',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('LUNCH BAG RED RETROSPOT', 'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('LUNCH BAG APPLE DESIGN', 'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('RABBIT NIGHT LIGHT', 'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('POSTAGE', 'RABBIT NIGHT LIGHT', 'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('PLASTERS IN TIN SPACEBOY', 'ROUND SNACK BOXES SET OF 4 FRUITS '): 11,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): 10,
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): 11,
#  ('ROUND SNACK BOXES SET OF 4 FRUITS ', 'SPACEBOY LUNCH BOX '): 12,
#  ('POSTAGE', 'ROUND SNACK BOXES SET OF 4 FRUITS ', 'SPACEBOY LUNCH BOX '): 11,
#  ('RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 12,
#  ('POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): 12,
#  ('POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 11,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 10,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): 11,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): 14,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): 14,
#  ('ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 25,
#  ('POSTAGE',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 23,
#  ('POSTAGE', 'ROUND SNACK BOXES SET OF 4 FRUITS '): 37,
#  ('LUNCH BAG WOODLAND', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('LUNCH BAG WOODLAND', 'POSTAGE', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('LUNCH BAG WOODLAND',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 10,
#  ('LUNCH BAG WOODLAND', 'PLASTERS IN TIN CIRCUS PARADE ', 'POSTAGE'): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'PLASTERS IN TIN SPACEBOY'): 10,
#  ('LUNCH BAG WOODLAND',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 11,
#  ('LUNCH BAG WOODLAND', 'PLASTERS IN TIN SPACEBOY', 'POSTAGE'): 11,
#  ('LUNCH BAG WOODLAND',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): 10,
#  ('LUNCH BAG WOODLAND', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 12,
#  ('LUNCH BAG WOODLAND', 'POSTAGE', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 11,
#  ('LUNCH BAG WOODLAND', 'RABBIT NIGHT LIGHT'): 12,
#  ('LUNCH BAG WOODLAND', 'POSTAGE', 'RABBIT NIGHT LIGHT'): 12,
#  ('LUNCH BAG WOODLAND', 'PLASTERS IN TIN WOODLAND ANIMALS'): 17,
#  ('LUNCH BAG WOODLAND', 'PLASTERS IN TIN WOODLAND ANIMALS', 'POSTAGE'): 15,
#  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG WOODLAND', 'SPACEBOY LUNCH BOX '): 10,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG WOODLAND',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'SPACEBOY LUNCH BOX '): 14,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): 12,
#  ('LUNCH BAG WOODLAND', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 16,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND'): 11,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'POSTAGE'): 10,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND'): 11,
#  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG WOODLAND', 'POSTAGE'): 17,
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND'): 15,
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'POSTAGE'): 14,
#  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND', 'POSTAGE'): 20,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG WOODLAND'): 25,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG WOODLAND', 'POSTAGE'): 21,
#  ('LUNCH BAG WOODLAND', 'POSTAGE'): 40,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'RABBIT NIGHT LIGHT'): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'RED TOADSTOOL LED NIGHT LIGHT'): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'POSTAGE',
#   'RED TOADSTOOL LED NIGHT LIGHT'): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BOX WITH CUTLERY RETROSPOT '): 12,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 10,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 12,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 12,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): 12,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): 12,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): 16,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE '): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY'): 15,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE'): 15,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): 12,
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY',
#   'SPACEBOY LUNCH BOX '): 10,
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY'): 11,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY'): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'PLASTERS IN TIN SPACEBOY', 'POSTAGE'): 17,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'SPACEBOY LUNCH BOX '): 10,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): 10,
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'SPACEBOY LUNCH BOX '): 15,
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): 11,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 17,
#  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG SPACEBOY DESIGN '): 25,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN '): 13,
#  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG SPACEBOY DESIGN ', 'POSTAGE'): 20,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'POSTAGE'): 13,
#  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '): 26,
#  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN ', 'POSTAGE'): 21,
#  ('LUNCH BAG SPACEBOY DESIGN ', 'POSTAGE'): 36,
#  ('LUNCH BAG RED RETROSPOT', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('LUNCH BAG RED RETROSPOT',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('POSTAGE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('SPACEBOY LUNCH BOX ', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('POSTAGE', 'SPACEBOY LUNCH BOX ', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'RED RETROSPOT MINI CASES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 13,
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('PLASTERS IN TIN SPACEBOY',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 14,
#  ('RED TOADSTOOL LED NIGHT LIGHT', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 14,
#  ('POSTAGE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 14,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 12,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 11,
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 15,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 10,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 17,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 25,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): 23,
#  ('POSTAGE', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): 45,
#  ('RED TOADSTOOL LED NIGHT LIGHT', 'SPACEBOY LUNCH BOX '): 10,
#  ('POSTAGE', 'RED TOADSTOOL LED NIGHT LIGHT', 'SPACEBOY LUNCH BOX '): 10,
#  ('RABBIT NIGHT LIGHT', 'SPACEBOY LUNCH BOX '): 10,
#  ('REGENCY CAKESTAND 3 TIER', 'SPACEBOY LUNCH BOX '): 11,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ', 'SPACEBOY LUNCH BOX '): 13,
#  ('LUNCH BAG APPLE DESIGN', 'SPACEBOY LUNCH BOX '): 13,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'SPACEBOY LUNCH BOX '): 10,
#  ('LUNCH BAG APPLE DESIGN', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 13,
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): 10,
#  ('PLASTERS IN TIN SPACEBOY', 'SPACEBOY LUNCH BOX '): 16,
#  ('PLASTERS IN TIN SPACEBOY', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 14,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'SPACEBOY LUNCH BOX '): 11,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): 10,
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 14,
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'SPACEBOY LUNCH BOX '): 10,
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'SPACEBOY LUNCH BOX '): 13,
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 13,
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): 11,
#  ('ROUND SNACK BOXES SET OF4 WOODLAND ', 'SPACEBOY LUNCH BOX '): 17,
#  ('POSTAGE', 'ROUND SNACK BOXES SET OF4 WOODLAND ', 'SPACEBOY LUNCH BOX '): 16,
#  ('LUNCH BAG RED RETROSPOT', 'SPACEBOY LUNCH BOX '): 21,
#  ('LUNCH BAG RED RETROSPOT', 'POSTAGE', 'SPACEBOY LUNCH BOX '): 13,
#  ('POSTAGE', 'SPACEBOY LUNCH BOX '): 38,
#  ('RED RETROSPOT MINI CASES', 'REGENCY CAKESTAND 3 TIER'): 10,
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ', 'REGENCY CAKESTAND 3 TIER'): 10,
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'REGENCY CAKESTAND 3 TIER'): 10,
#  ('PLASTERS IN TIN SPACEBOY', 'POSTAGE', 'REGENCY CAKESTAND 3 TIER'): 11,
#  ('REGENCY CAKESTAND 3 TIER', 'ROUND SNACK BOXES SET OF4 WOODLAND '): 12,
#  ('POSTAGE',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): 11,
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'REGENCY CAKESTAND 3 TIER'): 13,
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'REGENCY CAKESTAND 3 TIER'): 12,
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'REGENCY CAKESTAND 3 TIER'): 14,
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'POSTAGE', 'REGENCY CAKESTAND 3 TIER'): 13,
#  ('POSTAGE', 'REGENCY CAKESTAND 3 TIER'): 41,
#  ...}

# %% [markdown]
# Rules with minimum threshold confidence=0.7

# %%
rules=fp.generate_association_rules(patterns,0.7)
rules
# Out:
# {('CHILDRENS CUTLERY RETROSPOT RED ',): (('POSTAGE',), 1.0),
#  ('PINK  POLKADOT CUP',): (('POSTAGE',), 1.0),
#  ('RECYCLING BAG RETROSPOT ',): (('POSTAGE',), 1.0),
#  ('MINI JIGSAW CIRCUS PARADE ',): (('POSTAGE',), 0.9090909090909091),
#  ('VINTAGE HEADS AND TAILS CARD GAME ',): (('POSTAGE',), 0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE CHOCOLATE',): (('POSTAGE',), 1.0),
#  ('WORLD WAR 2 GLIDERS ASSTD DESIGNS',): (('POSTAGE',), 0.9090909090909091),
#  ('RAINY LADIES BIRTHDAY CARD',): (('POSTAGE',), 0.9090909090909091),
#  ('COFFEE MUG CAT + BIRD DESIGN',): (('POSTAGE',), 0.8333333333333334),
#  ('10 COLOUR SPACEBOY PEN',): (('POSTAGE',), 1.0),
#  ("CHILDREN'S CIRCUS PARADE MUG",): (('POSTAGE',), 1.0),
#  ('WRAP RED APPLES ',): (('POSTAGE',), 1.0),
#  ('EDWARDIAN PARASOL NATURAL',): (('POSTAGE',), 0.9166666666666666),
#  ('PACK OF 60 PINK PAISLEY CAKE CASES',): (('POSTAGE',), 0.8333333333333334),
#  ('PIGGY BANK RETROSPOT ',): (('POSTAGE',), 0.9166666666666666),
#  ('CAKE STAND WHITE TWO TIER LACE',): (('POSTAGE',), 0.9166666666666666),
#  ('RECYCLED ACAPULCO MAT TURQUOISE',): (('POSTAGE',), 0.9166666666666666),
#  ('SET OF 5 PANCAKE DAY MAGNETS',): (('POSTAGE',), 0.9166666666666666),
#  ('CARD DOLLY GIRL ',): (('SPACEBOY BIRTHDAY CARD',), 0.9166666666666666),
#  ('RED VINTAGE SPOT BEAKER',): (('POSTAGE',), 0.9166666666666666),
#  ('SET OF 12 MINI LOAF BAKING CASES',): (('POSTAGE',), 0.8333333333333334),
#  ('SET OF 6 TEA TIME BAKING CASES',): (('POSTAGE',), 0.9166666666666666),
#  ('STARS GIFT TAPE ',): (('POSTAGE',), 0.9230769230769231),
#  ('EDWARDIAN PARASOL RED',): (('POSTAGE',), 0.9230769230769231),
#  ('SKULLS  WATER TRANSFER TATTOOS ',): (('POSTAGE',), 0.9230769230769231),
#  ("POPPY'S PLAYHOUSE BATHROOM",): (("POPPY'S PLAYHOUSE BEDROOM ",
#    "POPPY'S PLAYHOUSE KITCHEN"),
#   0.7692307692307693),
#  ("POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE BEDROOM "): (("POPPY'S PLAYHOUSE KITCHEN",), 1.0),
#  ("POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE KITCHEN"): (("POPPY'S PLAYHOUSE BEDROOM ",),
#   0.8333333333333334),
#  ('EASTER TIN BUNNY BOUQUET',): (('POSTAGE',), 0.8461538461538461),
#  ('BLUE POLKADOT CUP',): (('POSTAGE',), 1.0),
#  ('RED RETROSPOT SHOPPING BAG',): (('POSTAGE',), 0.7692307692307693),
#  ('RED RETROSPOT PLATE ',): (('POSTAGE',), 0.9230769230769231),
#  ('PICNIC BOXES SET OF 3 RETROSPOT ',): (('ROUND SNACK BOXES SET OF 4 FRUITS ',),
#   0.7692307692307693),
#  ('LUNCH BAG  BLACK SKULL.',): (('LUNCH BAG RED RETROSPOT',),
#   0.7692307692307693),
#  ('LUNCH BAG DOILEY PATTERN ',): (('POSTAGE',), 0.8461538461538461),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('DOLLY GIRL CHILDRENS CUP',
#    'POSTAGE',
#    'SPACEBOY CHILDRENS BOWL'), 0.9090909090909091),
#  ('SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('DOLLY GIRL CHILDRENS CUP',
#    'POSTAGE'), 0.8333333333333334),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP'): (('SPACEBOY CHILDRENS BOWL',), 0.8666666666666667),
#  ('DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS CUP'): (('POSTAGE',
#    'SPACEBOY CHILDRENS BOWL'), 0.8333333333333334),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL'): (('DOLLY GIRL CHILDRENS CUP',), 0.7692307692307693),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS CUP'): (('DOLLY GIRL CHILDRENS CUP',
#    'SPACEBOY CHILDRENS BOWL'), 1.0),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('DOLLY GIRL CHILDRENS CUP', 'POSTAGE'),
#   0.9090909090909091),
#  ('POSTAGE',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('DOLLY GIRL CHILDRENS CUP',), 0.9090909090909091),
#  ('DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE'): (('DOLLY GIRL CHILDRENS BOWL',
#    'SPACEBOY CHILDRENS BOWL'), 0.7692307692307693),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE'): (('SPACEBOY CHILDRENS BOWL',), 0.8333333333333334),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS CUP'): (('POSTAGE', 'SPACEBOY CHILDRENS BOWL'),
#   0.9090909090909091),
#  ('DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS CUP'): (('SPACEBOY CHILDRENS BOWL',), 0.9090909090909091),
#  ('DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS BOWL'): (('DOLLY GIRL CHILDRENS BOWL',), 1.0),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS BOWL'): (('POSTAGE',), 0.7692307692307693),
#  ('DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('POSTAGE',), 0.9090909090909091),
#  ('DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL'): (('DOLLY GIRL CHILDRENS BOWL',), 1.0),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL'): (('SPACEBOY CHILDRENS CUP',), 1.0),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS CUP'): (('SPACEBOY CHILDRENS BOWL',), 1.0),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('POSTAGE',), 0.9090909090909091),
#  ('DOLLY GIRL CHILDRENS BOWL',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('DOLLY GIRL CHILDRENS CUP',), 1.0),
#  ('DOLLY GIRL CHILDRENS CUP',
#   'POSTAGE',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('DOLLY GIRL CHILDRENS BOWL',), 1.0),
#  ("POPPY'S PLAYHOUSE LIVINGROOM ",): (("POPPY'S PLAYHOUSE BEDROOM ",
#    "POPPY'S PLAYHOUSE KITCHEN"),
#   0.7142857142857143),
#  ("POPPY'S PLAYHOUSE BEDROOM ",
#   "POPPY'S PLAYHOUSE LIVINGROOM "): (("POPPY'S PLAYHOUSE KITCHEN",), 1.0),
#  ("POPPY'S PLAYHOUSE KITCHEN",
#   "POPPY'S PLAYHOUSE LIVINGROOM "): (("POPPY'S PLAYHOUSE BEDROOM ",),
#   0.8333333333333334),
#  ('3 PIECE SPACEBOY COOKIE CUTTER SET',): (('POSTAGE',), 0.9285714285714286),
#  ('JUMBO STORAGE BAG SUKI',): (('POSTAGE',), 0.9285714285714286),
#  ('SET OF 12 FAIRY CAKE BAKING CASES',): (('POSTAGE',), 0.7857142857142857),
#  ('MINI JIGSAW SPACEBOY',): (('POSTAGE',), 0.8666666666666667),
#  ('WOODLAND PARTY BAG + STICKER SET',): (('POSTAGE',
#    'RETROSPOT PARTY BAG + STICKER SET'),
#   0.8666666666666667),
#  ('POSTAGE',
#   'WOODLAND PARTY BAG + STICKER SET'): (('RETROSPOT PARTY BAG + STICKER SET',), 1.0),
#  ('RETROSPOT PARTY BAG + STICKER SET',
#   'WOODLAND PARTY BAG + STICKER SET'): (('POSTAGE',), 0.9285714285714286),
#  ('JUMBO BAG PINK POLKADOT',): (('POSTAGE',), 0.9333333333333333),
#  ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG WOODLAND ANIMALS'): (('POSTAGE',),
#   1.0),
#  ('JUMBO BAG PINK POLKADOT', 'POSTAGE'): (('JUMBO BAG WOODLAND ANIMALS',),
#   0.7142857142857143),
#  ('PACK OF 60 MUSHROOM CAKE CASES',): (('POSTAGE',), 0.9333333333333333),
#  ('PLASTERS IN TIN VINTAGE PAISLEY ',): (('POSTAGE',), 0.9333333333333333),
#  ('RED RETROSPOT UMBRELLA',): (('POSTAGE',), 0.8666666666666667),
#  ('RED RETROSPOT BOWL',): (('POSTAGE',), 0.8),
#  ('SET OF 10 LED DOLLY LIGHTS',): (('POSTAGE',), 0.7333333333333333),
#  ('POSTAGE', 'SPACEBOY MINI BACKPACK'): (('DOLLY GIRL MINI BACKPACK',),
#   0.7692307692307693),
#  ('POSTAGE', 'WOODLAND MINI BACKPACK'): (('DOLLY GIRL MINI BACKPACK',),
#   0.8571428571428571),
#  ('SPACEBOY MINI BACKPACK',
#   'WOODLAND MINI BACKPACK'): (('DOLLY GIRL MINI BACKPACK',), 0.9166666666666666),
#  ('DOLLY GIRL MINI BACKPACK', 'POSTAGE'): (('WOODLAND MINI BACKPACK',),
#   0.8571428571428571),
#  ('DOLLY GIRL MINI BACKPACK', 'WOODLAND MINI BACKPACK'): (('POSTAGE',),
#   0.8571428571428571),
#  ('ROBOT BIRTHDAY CARD',): (('POSTAGE',), 0.875),
#  ('JUMBO BAG VINTAGE LEAF',): (('POSTAGE',), 0.9375),
#  ('DOLLY GIRL CHILDRENS BOWL', 'POSTAGE'): (('SPACEBOY CHILDRENS BOWL',),
#   0.8666666666666667),
#  ('DOLLY GIRL CHILDRENS BOWL', 'SPACEBOY CHILDRENS BOWL'): (('POSTAGE',),
#   0.8125),
#  ('DOLLY GIRL MINI BACKPACK',): (('POSTAGE', 'WOODLAND MINI BACKPACK'), 0.75),
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN SPACEBOY',), 0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE RED '): (('POSTAGE',),
#   0.8571428571428571),
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED '): (('PLASTERS IN TIN SPACEBOY',),
#   0.8333333333333334),
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'POSTAGE'): (('ALARM CLOCK BAKELIKE RED ',), 1.0),
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE RED ',
#   'POSTAGE'): (('ALARM CLOCK BAKELIKE GREEN',), 0.8333333333333334),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK'): (('ALARM CLOCK BAKELIKE RED ',), 1.0),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE RED '): (('POSTAGE',), 0.8333333333333334),
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN SPACEBOY'): (('ALARM CLOCK BAKELIKE RED ',), 1.0),
#  ('ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN SPACEBOY'): (('ALARM CLOCK BAKELIKE GREEN',),
#   0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN SPACEBOY'): (('POSTAGE',), 0.8333333333333334),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'PLASTERS IN TIN SPACEBOY'): (('ALARM CLOCK BAKELIKE RED ',),
#   0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN SPACEBOY'): (('POSTAGE',), 0.8333333333333334),
#  ('ALARM CLOCK BAKELIKE ORANGE', 'POSTAGE'): (('ALARM CLOCK BAKELIKE RED ',),
#   0.8),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'POSTAGE'): (('ALARM CLOCK BAKELIKE RED ',), 0.9090909090909091),
#  ('CHILDS BREAKFAST SET CIRCUS PARADE',): (('POSTAGE',), 0.8235294117647058),
#  ('CHILDRENS APRON APPLES DESIGN',): (('POSTAGE',), 0.9411764705882353),
#  ('GINGERBREAD MAN COOKIE CUTTER',): (('POSTAGE',), 1.0),
#  ('GINGERBREAD MAN COOKIE CUTTER',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('POSTAGE',), 1.0),
#  ('CHARLOTTE BAG SUKI DESIGN',): (('POSTAGE',), 0.9411764705882353),
#  ('SPOTTY BUNTING',): (('POSTAGE',), 1.0),
#  ('SET OF 4 KNICK KNACK TINS LONDON ',): (('POSTAGE',), 0.7647058823529411),
#  ('ICE CREAM BUBBLES',): (('POSTAGE',), 1.0),
#  ('EDWARDIAN PARASOL BLACK',): (('POSTAGE',), 0.8888888888888888),
#  ('COFFEE MUG APPLES DESIGN', 'COFFEE MUG PEARS  DESIGN'): (('POSTAGE',),
#   0.8461538461538461),
#  ('COFFEE MUG PEARS  DESIGN', 'POSTAGE'): (('COFFEE MUG APPLES DESIGN',),
#   0.7333333333333333),
#  ('SET OF 20 KIDS COOKIE CUTTERS',): (('POSTAGE',), 0.8333333333333334),
#  ('ICE CREAM SUNDAE LIP GLOSS',): (('POSTAGE',), 0.7222222222222222),
#  ('POSTAGE', 'SPACEBOY CHILDRENS BOWL'): (('DOLLY GIRL CHILDRENS BOWL',),
#   0.7647058823529411),
#  ('RED RETROSPOT CUP',): (('POSTAGE',), 1.0),
#  ('TABLECLOTH RED APPLES DESIGN ',): (('POSTAGE',), 1.0),
#  ('SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'TABLECLOTH RED APPLES DESIGN '): (('POSTAGE',), 1.0),
#  ('RED RETROSPOT CAKE STAND',): (('POSTAGE',), 0.7368421052631579),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'SET OF 9 BLACK SKULL BALLOONS'): (('PACK OF 6 SKULL PAPER PLATES',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'SET OF 9 HEART SHAPED BALLOONS'): (('POSTAGE',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE'): (('PACK OF 6 SKULL PAPER PLATES',), 0.9333333333333333),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',
#    'POSTAGE',
#    'SET/20 RED RETROSPOT PAPER NAPKINS ',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.8333333333333334),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'PACK OF 6 SKULL PAPER PLATES',
#    'SET/20 RED RETROSPOT PAPER NAPKINS ',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.7692307692307693),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES'): (('POSTAGE',), 0.9411764705882353),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES'): (('POSTAGE',), 0.9333333333333333),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.8571428571428571),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9285714285714286),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER PLATES', 'POSTAGE'),
#   0.9166666666666666),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',
#    'SET/20 RED RETROSPOT PAPER NAPKINS '),
#   0.8571428571428571),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.9333333333333333),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE'): (('SET/6 RED SPOTTY PAPER CUPS',), 0.7857142857142857),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/20 RED RETROSPOT PAPER NAPKINS ',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.8333333333333334),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',
#    'SET/20 RED RETROSPOT PAPER NAPKINS ',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'SET/20 RED RETROSPOT PAPER NAPKINS ',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.7692307692307693),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER PLATES',),
#   0.9285714285714286),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER PLATES',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',
#    'POSTAGE',
#    'SET/20 RED RETROSPOT PAPER NAPKINS '),
#   0.8333333333333334),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'PACK OF 6 SKULL PAPER PLATES',
#    'SET/20 RED RETROSPOT PAPER NAPKINS '),
#   0.7692307692307693),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',),
#   0.8571428571428571),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',), 0.9285714285714286),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9285714285714286),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.9375),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',), 0.9166666666666666),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',),
#   0.8571428571428571),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.9285714285714286),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER CUPS',),
#   0.8461538461538461),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',),
#   0.8666666666666667),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/20 RED RETROSPOT PAPER NAPKINS '),
#   0.8333333333333334),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',
#    'SET/20 RED RETROSPOT PAPER NAPKINS '),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'SET/20 RED RETROSPOT PAPER NAPKINS '),
#   0.7692307692307693),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',),
#   0.8461538461538461),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE'): (('PACK OF 6 SKULL PAPER PLATES',), 0.8888888888888888),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE'): (('PACK OF 6 SKULL PAPER CUPS',), 0.875),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('PACK OF 6 SKULL PAPER CUPS',
#    'POSTAGE'),
#   0.8461538461538461),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.8461538461538461),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('PACK OF 6 SKULL PAPER CUPS',),
#   0.9166666666666666),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'PACK OF 6 SKULL PAPER PLATES',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9166666666666666),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('PACK OF 6 SKULL PAPER PLATES',
#    'POSTAGE'),
#   0.8461538461538461),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9230769230769231),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('PACK OF 6 SKULL PAPER PLATES',),
#   0.9166666666666666),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',
#    'POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.8461538461538461),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('POSTAGE',), 0.9166666666666666),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9166666666666666),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('SET/6 RED SPOTTY PAPER CUPS',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9166666666666666),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('SET/6 RED SPOTTY PAPER CUPS',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER CUPS',
#    'POSTAGE',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.8461538461538461),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER CUPS',
#    'PACK OF 6 SKULL PAPER PLATES',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER CUPS',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9166666666666666),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',), 1.0),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS', 'POSTAGE'),
#   0.8461538461538461),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER CUPS',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS', 'POSTAGE'),
#   0.8333333333333334),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',
#    'PACK OF 6 SKULL PAPER PLATES'),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',),
#   0.9166666666666666),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',), 0.9285714285714286),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER PLATES',
#    'POSTAGE',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',),
#   0.9230769230769231),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9166666666666666),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.9230769230769231),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PACK OF 6 SKULL PAPER PLATES',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   1.0),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',
#    'POSTAGE'),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',),
#   0.9166666666666666),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.9166666666666666),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',),
#   0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.9090909090909091),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER PLATES',), 1.0),
#  ('PACK OF 20 SKULL PAPER NAPKINS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 6 SKULL PAPER CUPS',),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('PACK OF 20 SKULL PAPER NAPKINS',),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'), 0.7647058823529411),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('SET/6 RED SPOTTY PAPER CUPS',),
#   0.8125),
#  ('PACK OF 6 SKULL PAPER CUPS', 'PACK OF 6 SKULL PAPER PLATES'): (('POSTAGE',),
#   0.95),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE'): (('PACK OF 20 SKULL PAPER NAPKINS',), 0.7368421052631579),
#  ('PACK OF 6 SKULL PAPER PLATES', 'POSTAGE'): (('PACK OF 6 SKULL PAPER CUPS',),
#   0.9047619047619048),
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG SUKI DESIGN '): (('POSTAGE',),
#   0.8571428571428571),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG SUKI DESIGN '): (('POSTAGE',), 0.9090909090909091),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SUKI DESIGN ',
#   'POSTAGE'): (('LUNCH BAG SPACEBOY DESIGN ',), 0.9090909090909091),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG SUKI DESIGN ',
#   'POSTAGE'): (('LUNCH BAG APPLE DESIGN',), 0.8333333333333334),
#  ('LUNCH BAG SUKI DESIGN ', 'POSTAGE'): (('LUNCH BAG SPACEBOY DESIGN ',),
#   0.75),
#  ('JUMBO BAG VINTAGE DOILY ',): (('POSTAGE',), 0.9473684210526315),
#  ('JUMBO BAG APPLES', 'JUMBO BAG VINTAGE DOILY '): (('POSTAGE',), 1.0),
#  ('PACK OF 20 NAPKINS RED APPLES',): (('POSTAGE',), 0.95),
#  ('POSTAGE',
#   'SKULL LUNCH BOX WITH CUTLERY '): (('STRAWBERRY LUNCH BOX WITH CUTLERY',),
#   0.7142857142857143),
#  ('SKULL LUNCH BOX WITH CUTLERY ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 0.9090909090909091),
#  ('BLUE HARMONICA IN BOX ',
#   'LUNCH BAG RED RETROSPOT'): (('RED  HARMONICA IN BOX ',), 1.0),
#  ('BLUE HARMONICA IN BOX ',
#   'RED  HARMONICA IN BOX '): (('LUNCH BAG RED RETROSPOT',), 1.0),
#  ('MINI LIGHTS WOODLAND MUSHROOMS', 'POSTAGE'): (('RABBIT NIGHT LIGHT',),
#   0.8823529411764706),
#  ('MINI LIGHTS WOODLAND MUSHROOMS', 'RABBIT NIGHT LIGHT'): (('POSTAGE',),
#   0.8823529411764706),
#  ('JAM MAKING SET PRINTED', 'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',),
#   0.9090909090909091),
#  ('SMALL RED RETROSPOT WINDMILL',): (('POSTAGE',), 0.8571428571428571),
#  ('PARTY BUNTING',): (('POSTAGE',), 0.9090909090909091),
#  ('CIRCUS PARADE CHILDRENS EGG CUP ',
#   'LUNCH BOX WITH CUTLERY RETROSPOT '): (('POSTAGE',), 0.9090909090909091),
#  ('CIRCUS PARADE CHILDRENS EGG CUP ',
#   'RED RETROSPOT MINI CASES'): (('POSTAGE',), 0.9090909090909091),
#  ('CIRCUS PARADE CHILDRENS EGG CUP ',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('POSTAGE',), 1.0),
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'PLASTERS IN TIN SKULLS'): (('POSTAGE',),
#   0.9166666666666666),
#  ('SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER PLATES'), 0.9285714285714286),
#  ('SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'), 0.9285714285714286),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.9285714285714286),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'SET OF 9 BLACK SKULL BALLOONS'): (('POSTAGE',), 0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET OF 9 BLACK SKULL BALLOONS'): (('POSTAGE',), 0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS'): (('PACK OF 6 SKULL PAPER PLATES',), 1.0),
#  ('PACK OF 6 SKULL PAPER PLATES',
#   'POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS'): (('PACK OF 6 SKULL PAPER CUPS',),
#   0.9090909090909091),
#  ('PACK OF 6 SKULL PAPER CUPS',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',), 0.8125),
#  ('PACK OF 6 SKULL PAPER CUPS', 'POSTAGE'): (('PACK OF 6 SKULL PAPER PLATES',),
#   0.7916666666666666),
#  ('CHILDRENS APRON SPACEBOY DESIGN',
#   'RETROSPOT CHILDRENS APRON'): (('POSTAGE',), 0.9090909090909091),
#  ('REVOLVER WOODEN RULER ',): (('POSTAGE',), 0.7727272727272727),
#  ('GUMBALL COAT RACK', 'LUNCH BOX WITH CUTLERY RETROSPOT '): (('POSTAGE',),
#   1.0),
#  ('GUMBALL COAT RACK', 'RED RETROSPOT MINI CASES'): (('POSTAGE',),
#   0.9230769230769231),
#  ('CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG'): (('POSTAGE',),
#   0.7692307692307693),
#  ('WATERING CAN PINK BUNNY',): (('POSTAGE',), 0.7391304347826086),
#  ('RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',), 0.9230769230769231),
#  ('RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.9090909090909091),
#  ('POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',),
#   0.8333333333333334),
#  ('POSTAGE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('RETROSPOT PARTY BAG + STICKER SET',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.9090909090909091),
#  ('RETROSPOT PARTY BAG + STICKER SET',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('POSTAGE',), 1.0),
#  ('JUMBO BAG SPACEBOY DESIGN', 'JUMBO BAG WOODLAND ANIMALS'): (('POSTAGE',),
#   1.0),
#  ('JUMBO BAG SPACEBOY DESIGN',
#   'PLASTERS IN TIN SPACEBOY'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.9090909090909091),
#  ('JUMBO BAG SPACEBOY DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.7692307692307693),
#  ('JUMBO BAG SPACEBOY DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('PLASTERS IN TIN WOODLAND ANIMALS',),
#   0.9166666666666666),
#  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG SPACEBOY DESIGN'): (('POSTAGE',),
#   0.9285714285714286),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('PLASTERS IN TIN SPACEBOY',
#    'PLASTERS IN TIN WOODLAND ANIMALS'), 0.9090909090909091),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN SPACEBOY',
#    'POSTAGE'), 0.8571428571428571),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN SPACEBOY'): (('POSTAGE',), 0.8666666666666667),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY'): (('PLASTERS IN TIN WOODLAND ANIMALS',),
#   0.9090909090909091),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN SPACEBOY',), 1.0),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.8571428571428571),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN', 'WOODLAND CHARLOTTE BAG'): (('POSTAGE',),
#   0.9090909090909091),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.9230769230769231),
#  ('CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): (('PLASTERS IN TIN SPACEBOY',), 1.0),
#  ('POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('POSTAGE',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('SET OF 9 HEART SHAPED BALLOONS',): (('POSTAGE',), 0.8461538461538461),
#  ('SET OF 9 BLACK SKULL BALLOONS',
#   'SET OF 9 HEART SHAPED BALLOONS'): (('POSTAGE',), 1.0),
#  ('JUMBO BAG APPLES', 'RABBIT NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('JUMBO BAG APPLES', 'JUMBO BAG WOODLAND ANIMALS'): (('POSTAGE',), 1.0),
#  ('JUMBO BAG APPLES', 'JUMBO BAG RED RETROSPOT'): (('POSTAGE',),
#   0.9230769230769231),
#  ('JUMBO BAG APPLES', 'LUNCH BAG APPLE DESIGN'): (('POSTAGE',),
#   0.8823529411764706),
#  ('CIRCUS PARADE LUNCH BOX ',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('PLASTERS IN TIN SPACEBOY',), 0.7692307692307693),
#  ('CIRCUS PARADE LUNCH BOX ',
#   'PLASTERS IN TIN SPACEBOY'): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.9090909090909091),
#  ('CIRCUS PARADE LUNCH BOX ', 'POSTAGE'): (('SPACEBOY LUNCH BOX ',),
#   0.7142857142857143),
#  ('CIRCUS PARADE LUNCH BOX ', 'SPACEBOY LUNCH BOX '): (('POSTAGE',),
#   0.8823529411764706),
#  ('CIRCUS PARADE LUNCH BOX ', 'LUNCH BOX I LOVE LONDON'): (('POSTAGE',),
#   0.8333333333333334),
#  ('LUNCH BOX I LOVE LONDON',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('PLASTERS IN TIN SPACEBOY',), 0.9166666666666666),
#  ('LUNCH BOX I LOVE LONDON',
#   'PLASTERS IN TIN SPACEBOY'): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.9166666666666666),
#  ('LUNCH BOX I LOVE LONDON', 'SPACEBOY LUNCH BOX '): (('POSTAGE',),
#   0.9230769230769231),
#  ('LUNCH BOX I LOVE LONDON',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.7692307692307693),
#  ('ASSORTED COLOUR MINI CASES', 'RED RETROSPOT MINI CASES'): (('POSTAGE',),
#   0.8888888888888888),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): (('POSTAGE',), 1.0),
#  ('RED TOADSTOOL LED NIGHT LIGHT',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): (('POSTAGE',), 1.0),
#  ('COFFEE MUG APPLES DESIGN',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): (('POSTAGE',), 1.0),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): (('POSTAGE',), 0.9230769230769231),
#  ('COFFEE MUG APPLES DESIGN', 'PLASTERS IN TIN CIRCUS PARADE '): (('POSTAGE',),
#   0.8461538461538461),
#  ('COFFEE MUG APPLES DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN CIRCUS PARADE ',), 1.0),
#  ('COFFEE MUG APPLES DESIGN',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): (('POSTAGE',), 1.0),
#  ('CHARLOTTE BAG APPLES DESIGN',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('POSTAGE',), 0.7142857142857143),
#  ('CHARLOTTE BAG APPLES DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN CIRCUS PARADE ',),
#   0.9230769230769231),
#  ('CHILDRENS CUTLERY DOLLY GIRL ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('CHILDRENS CUTLERY SPACEBOY ',), 0.9090909090909091),
#  ('CHILDRENS CUTLERY SPACEBOY ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('CHILDRENS CUTLERY DOLLY GIRL ',), 0.9090909090909091),
#  ('CHILDRENS CUTLERY DOLLY GIRL ',
#   'POSTAGE'): (('CHILDRENS CUTLERY SPACEBOY ',), 0.8947368421052632),
#  ('CHILDRENS CUTLERY SPACEBOY ',
#   'POSTAGE'): (('CHILDRENS CUTLERY DOLLY GIRL ',), 0.8947368421052632),
#  ('SPACEBOY BIRTHDAY CARD', 'TEA PARTY BIRTHDAY CARD'): (('POSTAGE',),
#   0.9166666666666666),
#  ('LUNCH BAG SPACEBOY DESIGN ', 'RED RETROSPOT PICNIC BAG'): (('POSTAGE',),
#   1.0),
#  ('LUNCH BAG RED RETROSPOT',
#   'RED RETROSPOT PICNIC BAG'): (('LUNCH BAG APPLE DESIGN', 'POSTAGE'),
#   0.7142857142857143),
#  ('LUNCH BAG APPLE DESIGN', 'RED RETROSPOT PICNIC BAG'): (('POSTAGE',), 1.0),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'RED RETROSPOT PICNIC BAG'): (('POSTAGE',), 1.0),
#  ('LUNCH BAG APPLE DESIGN',
#   'POSTAGE',
#   'RED RETROSPOT PICNIC BAG'): (('LUNCH BAG RED RETROSPOT',), 0.7142857142857143),
#  ('LUNCH BAG RED RETROSPOT',
#   'POSTAGE',
#   'RED RETROSPOT PICNIC BAG'): (('LUNCH BAG APPLE DESIGN',), 0.7142857142857143),
#  ('RED TOADSTOOL LED NIGHT LIGHT', 'WOODLAND CHARLOTTE BAG'): (('POSTAGE',),
#   1.0),
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'WOODLAND CHARLOTTE BAG'): (('POSTAGE',),
#   0.9090909090909091),
#  ('PLASTERS IN TIN SPACEBOY', 'WOODLAND CHARLOTTE BAG'): (('POSTAGE',),
#   0.9090909090909091),
#  ('RED RETROSPOT CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG'): (('POSTAGE',),
#   0.8235294117647058),
#  ('SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'SET/10 RED POLKADOT PARTY CANDLES'): (('POSTAGE',
#    'STRAWBERRY LUNCH BOX WITH CUTLERY'),
#   0.9090909090909091),
#  ('SET/10 RED POLKADOT PARTY CANDLES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'POSTAGE',
#   'SET/10 RED POLKADOT PARTY CANDLES'): (('STRAWBERRY LUNCH BOX WITH CUTLERY',),
#   1.0),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('POSTAGE',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('LUNCH BOX WITH CUTLERY RETROSPOT ',),
#   0.7142857142857143),
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG WOODLAND'): (('POSTAGE',), 1.0),
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG RED RETROSPOT'): (('POSTAGE',),
#   1.0),
#  ('JUMBO BAG WOODLAND ANIMALS',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 1.0),
#  ('JUMBO BAG WOODLAND ANIMALS', 'RABBIT NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG APPLE DESIGN'): (('POSTAGE',), 1.0),
#  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG WOODLAND ANIMALS'): (('POSTAGE',),
#   1.0),
#  ('ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN STRONGMAN'): (('ALARM CLOCK BAKELIKE GREEN',),
#   0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'PLASTERS IN TIN STRONGMAN'): (('ALARM CLOCK BAKELIKE RED ',), 0.9090909090909091),
#  ('PLASTERS IN TIN STRONGMAN', 'RED RETROSPOT MINI CASES'): (('POSTAGE',),
#   0.8333333333333334),
#  ('PLASTERS IN TIN STRONGMAN',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.8333333333333334),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN'): (('PLASTERS IN TIN WOODLAND ANIMALS',),
#   0.8461538461538461),
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'POSTAGE'): (('PLASTERS IN TIN CIRCUS PARADE ',), 1.0),
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN CIRCUS PARADE ',),
#   0.9166666666666666),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.8125),
#  ('PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.9285714285714286),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN STRONGMAN'): (('POSTAGE',), 0.8260869565217391),
#  ('PLASTERS IN TIN STRONGMAN',
#   'POSTAGE'): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.76),
#  ('PAPER BUNTING RETROSPOT',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',),
#   0.9090909090909091),
#  ('PAPER BUNTING RETROSPOT',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('LUNCH BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN SPACEBOY'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 1.0),
#  ('LUNCH BAG DOLLY GIRL DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN SPACEBOY',),
#   0.8461538461538461),
#  ('DOLLY GIRL LUNCH BOX',
#   'LUNCH BAG DOLLY GIRL DESIGN'): (('SPACEBOY LUNCH BOX ',), 0.9166666666666666),
#  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG DOLLY GIRL DESIGN'): (('POSTAGE',),
#   0.7857142857142857),
#  ('LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND'): (('POSTAGE',), 0.9230769230769231),
#  ('LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'SPACEBOY LUNCH BOX '): (('LUNCH BAG WOODLAND',), 0.7692307692307693),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND',
#   'SPACEBOY LUNCH BOX '): (('POSTAGE',), 0.8571428571428571),
#  ('LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG WOODLAND',
#   'POSTAGE'): (('LUNCH BAG SPACEBOY DESIGN ',), 0.8),
#  ('LUNCH BAG DOLLY GIRL DESIGN',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('LUNCH BAG WOODLAND',), 1.0),
#  ('LUNCH BAG DOLLY GIRL DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'POSTAGE'): (('LUNCH BAG WOODLAND',), 0.9230769230769231),
#  ('LUNCH BAG DOLLY GIRL DESIGN', 'POSTAGE'): (('LUNCH BAG WOODLAND',),
#   0.7142857142857143),
#  ('ALARM CLOCK BAKELIKE RED ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('ALARM CLOCK BAKELIKE RED ',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): (('POSTAGE',), 1.0),
#  ('ALARM CLOCK BAKELIKE RED ', 'RABBIT NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('ALARM CLOCK BAKELIKE PINK', 'MINI PAINT SET VINTAGE '): (('POSTAGE',),
#   0.7857142857142857),
#  ('ALARM CLOCK BAKELIKE RED ',
#   'MINI PAINT SET VINTAGE '): (('ALARM CLOCK BAKELIKE PINK',), 1.0),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'RED RETROSPOT MINI CASES'): (('ALARM CLOCK BAKELIKE RED ',), 1.0),
#  ('ALARM CLOCK BAKELIKE RED ',
#   'RED RETROSPOT MINI CASES'): (('ALARM CLOCK BAKELIKE GREEN',),
#   0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN CIRCUS PARADE ',
#    'PLASTERS IN TIN SPACEBOY'), 0.7692307692307693),
#  ('ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN SPACEBOY',), 1.0),
#  ('ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN CIRCUS PARADE ',),
#   0.7692307692307693),
#  ('ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.8333333333333334),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('ALARM CLOCK BAKELIKE PINK',
#    'PLASTERS IN TIN SPACEBOY'), 0.8461538461538461),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN SPACEBOY',), 1.0),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('ALARM CLOCK BAKELIKE PINK',),
#   0.8461538461538461),
#  ('ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): (('PLASTERS IN TIN SPACEBOY',), 1.0),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('ALARM CLOCK BAKELIKE RED ',), 1.0),
#  ('ALARM CLOCK BAKELIKE RED ',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('ALARM CLOCK BAKELIKE PINK',), 0.9166666666666666),
#  ('ALARM CLOCK BAKELIKE PINK', 'SPACEBOY LUNCH BOX '): (('POSTAGE',),
#   0.9230769230769231),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE PINK',
#   'SPACEBOY LUNCH BOX '): (('ALARM CLOCK BAKELIKE RED ',), 1.0),
#  ('ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
#   'SPACEBOY LUNCH BOX '): (('POSTAGE',), 0.9166666666666666),
#  ('ALARM CLOCK BAKELIKE PINK',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('ALARM CLOCK BAKELIKE RED ',), 0.9166666666666666),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN SPACEBOY'): (('PLASTERS IN TIN CIRCUS PARADE ',),
#   0.7692307692307693),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): (('ALARM CLOCK BAKELIKE RED ',), 0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): (('ALARM CLOCK BAKELIKE RED ',), 0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE PINK',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('PLASTERS IN TIN SPACEBOY',),
#   0.8333333333333334),
#  ('ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE RED ',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('ALARM CLOCK BAKELIKE PINK',),
#   0.9090909090909091),
#  ('ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED ',
# ...
#    'SET/6 RED SPOTTY PAPER PLATES'), 0.7142857142857143),
#  ('MINI PAINT SET VINTAGE ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   0.7142857142857143),
#  ('MINI PAINT SET VINTAGE ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',
#    'SET/6 RED SPOTTY PAPER CUPS'),
#   0.7142857142857143),
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('SET/6 RED SPOTTY PAPER CUPS',
#    'SET/6 RED SPOTTY PAPER PLATES'),
#   1.0),
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 1.0),
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('MINI PAINT SET VINTAGE ',
#   'POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',),
#   1.0),
#  ('MINI PAINT SET VINTAGE ',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.7142857142857143),
#  ('MINI PAINT SET VINTAGE ', 'PLASTERS IN TIN CIRCUS PARADE '): (('POSTAGE',),
#   0.8),
#  ('ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('RABBIT NIGHT LIGHT', 'ROUND SNACK BOXES SET OF 4 FRUITS '): (('POSTAGE',),
#   1.0),
#  ('PLASTERS IN TIN SPACEBOY',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.9090909090909091),
#  ('ROUND SNACK BOXES SET OF 4 FRUITS ', 'SPACEBOY LUNCH BOX '): (('POSTAGE',),
#   0.9166666666666666),
#  ('POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): (('ROUND SNACK BOXES SET OF4 WOODLAND ',),
#   0.9166666666666666),
#  ('RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.9166666666666666),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'ROUND SNACK BOXES SET OF 4 FRUITS '): (('POSTAGE',), 1.0),
#  ('ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.92),
#  ('LUNCH BAG WOODLAND', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',),
#   1.0),
#  ('LUNCH BAG WOODLAND',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.9090909090909091),
#  ('LUNCH BAG WOODLAND',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.9090909090909091),
#  ('LUNCH BAG WOODLAND', 'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',),
#   0.9166666666666666),
#  ('LUNCH BAG WOODLAND', 'RABBIT NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('LUNCH BAG WOODLAND', 'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',),
#   0.8823529411764706),
#  ('LUNCH BAG APPLE DESIGN',
#   'SPACEBOY LUNCH BOX '): (('LUNCH BAG RED RETROSPOT',
#    'POSTAGE'), 0.7692307692307693),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG WOODLAND',
#   'SPACEBOY LUNCH BOX '): (('POSTAGE',), 1.0),
#  ('LUNCH BAG APPLE DESIGN',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('LUNCH BAG RED RETROSPOT',), 0.7692307692307693),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('LUNCH BAG WOODLAND',), 0.7058823529411765),
#  ('LUNCH BAG WOODLAND',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('LUNCH BAG SPACEBOY DESIGN ',), 0.75),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND'): (('POSTAGE',), 0.9090909090909091),
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'LUNCH BAG WOODLAND'): (('POSTAGE',), 0.9333333333333333),
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'POSTAGE'): (('LUNCH BAG SPACEBOY DESIGN ',), 0.7),
#  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG WOODLAND'): (('POSTAGE',), 0.84),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('PLASTERS IN TIN SPACEBOY',),
#   0.9090909090909091),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('PLASTERS IN TIN CIRCUS PARADE ',),
#   0.9090909090909091),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY'): (('POSTAGE',), 0.8),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN SPACEBOY',),
#   0.9166666666666666),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.75),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.7058823529411765),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): (('PLASTERS IN TIN SPACEBOY',), 1.0),
#  ('LUNCH BAG SPACEBOY DESIGN ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE'): (('PLASTERS IN TIN SPACEBOY',), 0.8),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'SPACEBOY LUNCH BOX '): (('POSTAGE',), 1.0),
#  ('LUNCH BAG RED RETROSPOT',
#   'SPACEBOY LUNCH BOX '): (('LUNCH BAG SPACEBOY DESIGN ',),
#   0.7142857142857143),
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN ',
#   'SPACEBOY LUNCH BOX '): (('POSTAGE',), 0.7333333333333333),
#  ('LUNCH BAG RED RETROSPOT',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('LUNCH BAG APPLE DESIGN',), 0.7692307692307693),
#  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG SPACEBOY DESIGN '): (('POSTAGE',), 0.8),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN '): (('POSTAGE',), 1.0),
#  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '): (('POSTAGE',),
#   0.8076923076923077),
#  ('LUNCH BAG RED RETROSPOT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('SPACEBOY LUNCH BOX ', 'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',),
#   1.0),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'RED RETROSPOT MINI CASES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 0.9090909090909091),
#  ('POSTAGE',
#   'RED RETROSPOT MINI CASES',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('LUNCH BOX WITH CUTLERY RETROSPOT ',),
#   0.7692307692307693),
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('PLASTERS IN TIN SPACEBOY',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('PLASTERS IN TIN CIRCUS PARADE ',),
#   0.7857142857142857),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('RED TOADSTOOL LED NIGHT LIGHT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 1.0),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 0.9166666666666666),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('PLASTERS IN TIN CIRCUS PARADE ',),
#   0.7333333333333333),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('POSTAGE',), 0.92),
#  ('RED TOADSTOOL LED NIGHT LIGHT', 'SPACEBOY LUNCH BOX '): (('POSTAGE',), 1.0),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'SPACEBOY LUNCH BOX '): (('POSTAGE',), 1.0),
#  ('PLASTERS IN TIN SPACEBOY',
#   'SPACEBOY LUNCH BOX '): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.8125),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'SPACEBOY LUNCH BOX '): (('POSTAGE',), 0.9090909090909091),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('PLASTERS IN TIN SPACEBOY',), 0.7142857142857143),
#  ('PLASTERS IN TIN SPACEBOY',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('PLASTERS IN TIN WOODLAND ANIMALS',),
#   0.7857142857142857),
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'SPACEBOY LUNCH BOX '): (('POSTAGE',), 0.8461538461538461),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'SPACEBOY LUNCH BOX '): (('PLASTERS IN TIN SPACEBOY',), 0.8461538461538461),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND ', 'SPACEBOY LUNCH BOX '): (('POSTAGE',),
#   0.9411764705882353),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'REGENCY CAKESTAND 3 TIER'): (('POSTAGE',), 0.9230769230769231),
#  ('REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.9166666666666666),
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'REGENCY CAKESTAND 3 TIER'): (('POSTAGE',),
#   0.9285714285714286),
#  ('LUNCH BAG APPLE DESIGN', 'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',),
#   0.9230769230769231),
#  ('LUNCH BAG APPLE DESIGN',
#   'LUNCH BOX WITH CUTLERY RETROSPOT '): (('POSTAGE',), 0.8),
#  ('LUNCH BAG APPLE DESIGN', 'PLASTERS IN TIN CIRCUS PARADE '): (('POSTAGE',),
#   0.8235294117647058),
#  ('LUNCH BAG APPLE DESIGN', 'RABBIT NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG RED RETROSPOT'): (('POSTAGE',),
#   0.9230769230769231),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',), 0.8461538461538461),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PLASTERS IN TIN CIRCUS PARADE ',),
#   0.7142857142857143),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 1.0),
#  ('POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('SET/6 RED SPOTTY PAPER CUPS',),
#   0.7674418604651163),
#  ('POSTAGE',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 0.9523809523809523),
#  ('SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('POSTAGE',), 0.825),
#  ('POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',),
#   0.9696969696969697),
#  ('POSTAGE',
#   'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',),
#   0.9696969696969697),
#  ('POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',), 0.8),
#  ('SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.8205128205128205),
#  ('SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('POSTAGE',), 0.8333333333333334),
#  ('POSTAGE',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/20 RED RETROSPOT PAPER NAPKINS ',),
#   0.717391304347826),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('SET/6 RED SPOTTY PAPER CUPS',), 0.8333333333333334),
#  ('RED TOADSTOOL LED NIGHT LIGHT',
#   'SET/20 RED RETROSPOT PAPER NAPKINS '): (('POSTAGE',), 0.8333333333333334),
#  ('LUNCH BAG RED RETROSPOT', 'RED RETROSPOT MINI CASES'): (('POSTAGE',), 1.0),
#  ('RABBIT NIGHT LIGHT', 'RED RETROSPOT MINI CASES'): (('POSTAGE',),
#   0.9166666666666666),
#  ('RED RETROSPOT MINI CASES', 'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',),
#   0.875),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'RED RETROSPOT MINI CASES'): (('POSTAGE',), 0.8),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES'): (('PLASTERS IN TIN SPACEBOY',), 0.7058823529411765),
#  ('PLASTERS IN TIN SPACEBOY',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES'): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.8571428571428571),
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'RED RETROSPOT MINI CASES'): (('POSTAGE',),
#   0.85),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'RED RETROSPOT MINI CASES'): (('POSTAGE',), 0.7692307692307693),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE',
#   'RED RETROSPOT MINI CASES'): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.7692307692307693),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'RED RETROSPOT MINI CASES'): (('POSTAGE',), 0.8),
#  ('RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.85),
#  ('PLASTERS IN TIN SPACEBOY',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('PLASTERS IN TIN WOODLAND ANIMALS',
#    'POSTAGE'),
#   0.7692307692307693),
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('PLASTERS IN TIN SPACEBOY',
#   'POSTAGE',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.7692307692307693),
#  ('LUNCH BAG RED RETROSPOT', 'PLASTERS IN TIN CIRCUS PARADE '): (('POSTAGE',),
#   0.9166666666666666),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.75),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('PLASTERS IN TIN SPACEBOY',),
#   0.9230769230769231),
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.7142857142857143),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'POSTAGE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('PLASTERS IN TIN SPACEBOY',),
#   0.7058823529411765),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.8095238095238095),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.7777777777777778),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.7241379310344828),
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.8048780487804879),
#  ('PLASTERS IN TIN SPACEBOY',
#   'POSTAGE'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.7333333333333333),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('PLASTERS IN TIN WOODLAND ANIMALS',),
#   0.8333333333333334),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ', 'RABBIT NIGHT LIGHT'): (('POSTAGE',),
#   1.0),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.8823529411764706),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.7692307692307693),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'POSTAGE'): (('PLASTERS IN TIN CIRCUS PARADE ',), 0.8333333333333334),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT ',
#   'PLASTERS IN TIN CIRCUS PARADE '): (('POSTAGE',), 0.8421052631578947),
#  ('LUNCH BAG RED RETROSPOT',
#   'LUNCH BOX WITH CUTLERY RETROSPOT '): (('POSTAGE',), 0.75),
#  ('LUNCH BAG RED RETROSPOT', 'RABBIT NIGHT LIGHT'): (('POSTAGE',),
#   0.8461538461538461),
#  ('LUNCH BAG RED RETROSPOT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 0.9285714285714286),
#  ('LUNCH BAG RED RETROSPOT', 'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',),
#   0.9333333333333333),
#  ('RED TOADSTOOL LED NIGHT LIGHT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',), 1.0),
#  ('RABBIT NIGHT LIGHT', 'ROUND SNACK BOXES SET OF4 WOODLAND '): (('POSTAGE',),
#   1.0),
#  ('PLASTERS IN TIN CIRCUS PARADE ', 'RABBIT NIGHT LIGHT'): (('POSTAGE',),
#   0.9375),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('PLASTERS IN TIN CIRCUS PARADE ',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('POSTAGE',), 0.825),
#  ('PLASTERS IN TIN WOODLAND ANIMALS', 'RABBIT NIGHT LIGHT'): (('POSTAGE',),
#   0.8666666666666667),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',), 1.0),
#  ('RABBIT NIGHT LIGHT', 'RED TOADSTOOL LED NIGHT LIGHT'): (('POSTAGE',),
#   0.7619047619047619),
#  ('RABBIT NIGHT LIGHT',): (('POSTAGE',), 0.8783783783783784)}

# %%
def inspect(rules):
    lhs = [rule for rule in rules]
    rhs = [rules[rule][0] for rule in rules]
    supports = [rules[rule][1] for rule in rules]
    return list(zip(lhs, rhs, supports))

resultsinDataFrame= pd.DataFrame(inspect(rules), columns=['Left Hand Side', 'Right Hand Side', 'Confidence'])
resultsinDataFrame
# Out:
#                                         Left Hand Side Right Hand Side  \
# 0                  (CHILDRENS CUTLERY RETROSPOT RED ,)      (POSTAGE,)
# 1                                (PINK  POLKADOT CUP,)      (POSTAGE,)
# 2                          (RECYCLING BAG RETROSPOT ,)      (POSTAGE,)
# 3                        (MINI JIGSAW CIRCUS PARADE ,)      (POSTAGE,)
# 4                (VINTAGE HEADS AND TAILS CARD GAME ,)      (POSTAGE,)
# ..                                                 ...             ...
# 569  (PLASTERS IN TIN CIRCUS PARADE , PLASTERS IN T...      (POSTAGE,)
# 570  (PLASTERS IN TIN WOODLAND ANIMALS, RABBIT NIGH...      (POSTAGE,)
# 571  (PLASTERS IN TIN WOODLAND ANIMALS, RED TOADSTO...      (POSTAGE,)
# 572  (RABBIT NIGHT LIGHT, RED TOADSTOOL LED NIGHT L...      (POSTAGE,)
# 573                              (RABBIT NIGHT LIGHT,)      (POSTAGE,)
#
#      Confidence
# 0      1.000000
# 1      1.000000
# 2      1.000000
# 3      0.909091
# 4      0.909091
# ..          ...
# 569    0.825000
# 570    0.866667
# 571    1.000000
# 572    0.761905
# 573    0.878378
#
# [574 rows x 3 columns]

# %%
resultsinDataFrame[resultsinDataFrame['Right Hand Side']!=('POSTAGE',)]
# Out:
#                                         Left Hand Side  \
# 18                                 (CARD DOLLY GIRL ,)
# 25                       (POPPY'S PLAYHOUSE BATHROOM,)
# 26   (POPPY'S PLAYHOUSE BATHROOM, POPPY'S PLAYHOUSE...
# 27   (POPPY'S PLAYHOUSE BATHROOM, POPPY'S PLAYHOUSE...
# 32                 (PICNIC BOXES SET OF 3 RETROSPOT ,)
# ..                                                 ...
# 547  (PLASTERS IN TIN CIRCUS PARADE , POSTAGE, ROUN...
# 550  (PLASTERS IN TIN CIRCUS PARADE , PLASTERS IN T...
# 552                (PLASTERS IN TIN SPACEBOY, POSTAGE)
# 553  (PLASTERS IN TIN CIRCUS PARADE , SET/6 RED SPO...
# 558  (LUNCH BOX WITH CUTLERY RETROSPOT , PLASTERS I...
#
#                                        Right Hand Side  Confidence
# 18                           (SPACEBOY BIRTHDAY CARD,)    0.916667
# 25   (POPPY'S PLAYHOUSE BEDROOM , POPPY'S PLAYHOUSE...    0.769231
# 26                        (POPPY'S PLAYHOUSE KITCHEN,)    1.000000
# 27                       (POPPY'S PLAYHOUSE BEDROOM ,)    0.833333
# 32               (ROUND SNACK BOXES SET OF 4 FRUITS ,)    0.769231
# ..                                                 ...         ...
# 547                        (PLASTERS IN TIN SPACEBOY,)    0.705882
# 550                (PLASTERS IN TIN WOODLAND ANIMALS,)    0.724138
# 552                (PLASTERS IN TIN WOODLAND ANIMALS,)    0.733333
# 553                (PLASTERS IN TIN WOODLAND ANIMALS,)    0.833333
# 558                  (PLASTERS IN TIN CIRCUS PARADE ,)    0.833333
#
# [296 rows x 3 columns]
